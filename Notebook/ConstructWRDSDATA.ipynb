# %% [markdown]
# # Step 1: Construct Quarterly Variables
# The calculations for these variables will involve aggregating data from the IBES dataset. You will need the following information from the IBES database:
#
# - ANALYSTS: The number of analysts providing earnings per share (EPS) forecasts.
# - DISPERSION: The standard deviation of the analyst EPS forecasts, normalized by the share price at the end of the previous quarter.
# - FCSTERROR: The absolute value of the difference between the mean analyst EPS forecast and the actual EPS, normalized by the share price at the end of the previous quarter.
#
# ## Step 1.1: Extract Required Data from WRDS IBES
# Here, we'll extract the relevant data from the IBES dataset, which includes:
#
# - The number of analyst estimates (numest)
# - The mean analyst estimate (meanest)
# - The standard deviation of analyst estimates (stdev)
# - The actual EPS value (actual)
# - The forecast period end date (fpedats)
# - The share price from Compustat for the previous quarter (prccq)

# %%
import os

import wrds
import pandas as pd
import numpy as np

from Constants import Constants as const
from Utilities import get_fama_french_industry

# %%
# Connect to WRDS
conn = wrds.Connection()

# %%
begin_date = '2006-01-01'
end_date = '2016-12-31'

import pandas as pd

years = range(2006, 2017)
all_data = []

for year in years:
    print(year)
    begin_date = f'{year}-01-01'
    end_date = f'{year}-12-31'
    ibes_query = f"""
        SELECT a.ticker, a.fpedats, a.anndats_act, a.meanest, a.numest, a.stdev, a.actual, b.prccq, b.fyearq, b.fqtr
        FROM ibes.statsum_epsus AS a
        JOIN comp.funda AS b ON a.ticker = b.tic AND a.fpedats = b.datadate
        WHERE a.measure = 'EPS'
          AND a.fpedats BETWEEN '{begin_date}' AND '{end_date}'
    """
    ibes_data_chunk = conn.raw_sql(ibes_query)
    all_data.append(ibes_data_chunk)

# Combine all chunks into one DataFrame
ibes_data = pd.concat(all_data)
# Out:
# 2006
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# UndefinedColumn: column a.fyearq does not exist
# LINE 4: ...     JOIN comp.fundq AS b ON a.ticker = b.tic AND a.fyearq =...
#                                                              ^
# HINT:  Perhaps you meant to reference the column "b.fyearq".
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[10], line 20
#      12     end_date = f'{year}-12-31'
#      13     ibes_query = f"""
#      14         SELECT a.ticker, a.fpedats, a.anndats_act, a.meanest, a.numest, a.stdev, a.actual, b.prccq, b.fyearq, b.fqtr
#      15         FROM ibes.statsum_epsus AS a
#    (...)
#      18           AND a.fpedats BETWEEN '{begin_date}' AND '{end_date}'
#      19     """
# ---> 20     ibes_data_chunk = conn.raw_sql(ibes_query)
#      21     all_data.append(ibes_data_chunk)
#      23 # Combine all chunks into one DataFrame
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\wrds\sql.py:583, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter)
#     581         return full_df
#     582 except sa.exc.ProgrammingError as e:
# --> 583     raise e
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\wrds\sql.py:566, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter)
#     509 """
#     510 Queries the database using a raw SQL string.
#     511
#    (...)
#     562     2003-09-10  09:35:20.709000  N       AA       None     None  108100.0  28.200          N      00  1.929947e+15         C  None
#     563 """  # noqa
#     565 try:
# --> 566     df = pd.read_sql_query(
#     567         sql,
#     568         self.connection,
#     569         coerce_float=coerce_float,
#     570         parse_dates=date_cols,
#     571         index_col=index_col,
#     572         chunksize=chunksize,
#     573         params=params,
#     574     )
#     575     if return_iter or chunksize is None:
#     576         return df
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File D:\Users\wangy\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column a.fyearq does not exist
# LINE 4: ...     JOIN comp.fundq AS b ON a.ticker = b.tic AND a.fyearq =...
#                                                              ^
# HINT:  Perhaps you meant to reference the column "b.fyearq".
#
# [SQL:
#         SELECT a.ticker, a.fpedats, a.anndats_act, a.meanest, a.numest, a.stdev, a.actual, b.prccq, b.fyearq, b.fqtr
#         FROM ibes.statsum_epsus AS a
#         JOIN comp.fundq AS b ON a.ticker = b.tic AND a.fyearq = b.fyearq AND a.fqtr = b.fqtr
#         WHERE a.measure = 'EPS'
#           AND a.fpedats BETWEEN '2006-01-01' AND '2006-12-31'
#     ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Check available libraries in WRDS
available_libraries = conn.list_libraries()
print("Available Libraries in WRDS:", available_libraries)

# Check available tables in the Compustat library if it's there
if 'compustat' in available_libraries:
    available_tables = conn.list_tables(library='compustat')
    print("Tables in Compustat Library:", available_tables)
elif 'compustat_na' in available_libraries:
    available_tables = conn.list_tables(library='compustat_na')
    print("Tables in Compustat North America Library:", available_tables)
else:
    print("Compustat library not found in WRDS.")
# Out:
# Available Libraries in WRDS: ['aha_sample', 'ahasamp', 'audit', 'audit_audit_comp', 'audit_common', 'audit_corp_legal', 'audit_oia', 'auditsmp', 'auditsmp_all', 'bank', 'bank_all', 'bank_premium_samp', 'banksamp', 'block', 'block_all', 'boardex', 'boardex_na', 'boardex_trial', 'boardsmp', 'bvd_amadeus_trial', 'bvd_bvdbankf_trial', 'bvd_orbis_trial', 'bvdsamp', 'calcbench_trial', 'calcbnch', 'cboe', 'cboe_all', 'cboe_sample', 'cboesamp', 'ciq', 'ciq_common', 'ciqsamp', 'ciqsamp_capstrct', 'ciqsamp_common', 'ciqsamp_keydev', 'ciqsamp_pplintel', 'ciqsamp_ratings', 'ciqsamp_transactions', 'ciqsamp_transcripts', 'cisdmsmp', 'columnar', 'comp', 'comp_bank', 'comp_bank_daily', 'comp_execucomp', 'comp_global', 'comp_global_daily', 'comp_na_annual_all', 'comp_na_daily_all', 'comp_na_monthly_all', 'comp_segments_hist', 'comp_segments_hist_daily', 'compa', 'compb', 'compg', 'compm', 'compsamp', 'compsamp_all', 'compsamp_snapshot', 'compseg', 'contrib', 'contrib_as_filed_financials', 'contrib_ceo_turnover', 'contrib_char_returns', 'contrib_general', 'contrib_global_factor', 'contrib_intangible_value', 'contrib_kpss', 'contrib_liva', 'crsp', 'crsp_a_ccm', 'crsp_a_indexes', 'crsp_a_stock', 'crsp_q_mutualfunds', 'crspsamp', 'crspsamp_all', 'crspsamp_mf', 'csmsamp_all', 'dealscan', 'djones', 'djones_all', 'dmef', 'dmef_all', 'doe', 'doe_all', 'etfg_samp', 'etfgsamp', 'eurekahedge_sample', 'eursamp', 'eventus', 'evts_all', 'execcomp', 'factsamp_all', 'factsamp_revere', 'ff', 'ff_all', 'fjc', 'fjc_linking', 'fjc_litigation', 'frb', 'frb_all', 'fssamp', 'ftsesamp', 'ftsesamp_russell_us', 'gutenberg', 'hfrsamp', 'hfrsamp_hfrdb', 'ibes', 'ibessamp_kpi', 'ifgrsamp', 'ims_obp_trial', 'imssamp', 'infogroupsamp_business', 'infogroupsamp_residential', 'insdsamp', 'iri', 'iri_all', 'iss_va_mf', 'iss_va_vote_us', 'issm', 'issm_nasd1987', 'issm_nasd1988', 'issm_nasd1989', 'issm_nasd1990', 'issm_nasd1991', 'issm_nasd1992', 'issm_nyam1983', 'issm_nyam1984', 'issm_nyam1985', 'issm_nyam1986', 'issm_nyam1987', 'issm_nyam1988', 'issm_nyam1989', 'issm_nyam1990', 'issm_nyam1991', 'issm_nyam1992', 'kpisamp', 'ktmine_patents_samp', 'ktsamp', 'lvnsamp', 'lvnsamp_all', 'macrofin', 'macrofin_comm_trade', 'mfl', 'mflinks_all', 'midas', 'morningstarsamp_cisdm', 'mrktsamp', 'mrktsamp_cds', 'mrktsamp_cdx', 'mrktsamp_msf', 'msci_esg_samp', 'msciesmp', 'msrb', 'msrb_all', 'msrbsamp', 'msrbsamp_all', 'omtrial', 'optionm', 'optionm_all', 'optionmsamp_europe', 'optionmsamp_us', 'otc', 'otc_endofday', 'phlx', 'phlx_all', 'pitchsmp', 'ppubsamp', 'ppubsamp_d4d', 'ppubsamp_rx_checkup', 'preqin', 'preqin_cashflow', 'preqin_deals', 'preqin_gp', 'preqin_lp', 'preqin_pe', 'preqin_vc', 'preqsamp', 'preqsamp_all', 'public', 'public_all', 'pwt', 'pwt_all', 'ravenpack_common', 'ravenpack_dj', 'ravenpack_trial', 'reprisk_sample', 'repsamp', 'revelio_samp', 'revsamp', 'risk', 'risk_directors', 'risk_governance', 'risksamp', 'risksamp_all', 'rpna', 'rpnasamp', 'rq_all', 'rstat_samp', 'rstatsmp', 'sdc', 'sdcsamp', 'secsamp', 'secsamp_all', 'snapsamp', 'snl', 'snl_fundamentals', 'snlsamp', 'snlsamp_fig', 'sp_esg', 'sustainalyticssamp_all', 'sustsamp', 'taqm_2014', 'taqm_2015', 'taqm_2016', 'taqm_2017', 'taqm_2018', 'taqm_2019', 'taqm_2020', 'taqm_2021', 'taqm_2022', 'taqm_2023', 'taqm_2024', 'taqmsamp', 'taqmsamp_all', 'taqmsec', 'taqsamp', 'taqsamp_all', 'tfn', 'totalq', 'totalq_all', 'tr_13f', 'tr_common', 'tr_dealscan', 'tr_ds_comds', 'tr_ds_econ', 'tr_ds_equities', 'tr_ds_fut', 'tr_ibes', 'tr_mutualfunds', 'tr_sdc_ma', 'tr_sdc_ni', 'tr_sdc_samples', 'tr_worldscope', 'trace', 'trace_enhanced', 'trace_standard', 'trcommon', 'trcstsmp', 'trdbdmismp', 'trdbwbsmp', 'trdssamp', 'trdstrm', 'tresgsmp', 'trsamp', 'trsamp_all', 'trsamp_db_dmi', 'trsamp_db_wb', 'trsamp_ds_eq', 'trsamp_dscom', 'trsamp_dsecon', 'trsamp_dsfut', 'trsamp_esg', 'trsamp_sdc_ma', 'trsamp_sdc_ni', 'trsamp_worldscope', 'trucost', 'trucost_common', 'trucost_environ', 'trucost_fossilfuel', 'trucost_samp', 'trucost_sector_ff', 't ...
# Compustat library not found in WRDS.

# %% [markdown]
# ## Step 1.2: Calculate Quarterly Variables
# 1. ANALYSTS: The number of analysts providing earnings per share forecasts.
# Use the numest column from IBES.
#
# 2. DISPERSION: The standard deviation of analyst EPS forecasts normalized by the share price at the end of the previous quarter.
# Calculation: DISPERSION = stdev / prccq
# Where stdev is the standard deviation of analyst forecasts and prccq is the share price at the end of the previous quarter.
#
# 3. FCSTERROR: The absolute forecast error.
#
# Calculation: FCSTERROR = abs(meanest - actual) / prccq
# Where meanest is the mean analyst EPS forecast, and actual is the actual EPS value.

# %%
# Calculate ANALYSTS, DISPERSION, and FCSTERROR
ibes_data['analysts'] = ibes_data['numest']
ibes_data['dispersion'] = ibes_data['stdev'] / ibes_data['prccq']
ibes_data['fcsterror'] = abs(ibes_data['meanest'] - ibes_data['actual']) / ibes_data['prccq']

# Display the first few rows to verify the calculations
ibes_data[['ticker', 'fpedats', 'analysts', 'dispersion', 'fcsterror']].head()

# %% [markdown]
# ## Step 2.1: Update SQL Query for Annual Data Extraction
#
# To create annual variables, we will extract data from an annual financial dataset instead of the quarterly fundq dataset. In Compustat, this is often done using the fundamental annual (fundann) dataset.
#
# We will adjust the SQL query to access annual earnings and price data from IBES and Compustat.
#
# Here's the modified version:

# %%
# Define the time range for the data extraction
begin_date = '2006-01-01'
end_date = '2016-12-31'

# SQL query to extract annual data from IBES and Compustat, joining on ticker and a date range
ibes_query_annual = f"""
    SELECT a.ticker, a.fpedats, a.anndats_act, a.meanest, a.numest, a.stdev, a.actual, b.prcc_f, b.fyear
    FROM ibes.statsum_epsus AS a
    JOIN comp.funda AS b ON a.ticker = b.tic
    WHERE a.measure = 'EPS'
      AND a.fpedats BETWEEN b.datadate AND b.datadate + interval '1 year' - interval '1 day'
      AND a.fpedats BETWEEN '{begin_date}' AND '{end_date}'
"""

# Extract data using the WRDS connection
ibes_data_annual = conn.raw_sql(ibes_query_annual)

# Convert fpedats and anndats_act to datetime
ibes_data_annual['fpedats'] = pd.to_datetime(ibes_data_annual['fpedats'])
ibes_data_annual['anndats_act'] = pd.to_datetime(ibes_data_annual['anndats_act'])

# Display the first few rows
ibes_data_annual.head()
# Out:
#   ticker    fpedats anndats_act  meanest  numest  stdev  actual  prcc_f  \
# 0   AAAP 2015-12-31  2016-04-29    -0.30     3.0   0.07   -0.25   31.27
# 1     AA 2011-12-31  2012-01-09     3.76    15.0   0.92    2.16     NaN
# 2     AA 2011-12-31  2012-01-09     3.84    15.0   0.81    2.16     NaN
# 3     AA 2011-12-31  2012-01-09     3.92    15.0   0.67    2.16     NaN
# 4     AA 2011-12-31  2012-01-09     4.03    14.0   0.43    2.16     NaN
#
#     fyear
# 0  2015.0
# 1  2011.0
# 2  2011.0
# 3  2011.0
# 4  2011.0

# %%
# Find the index of the rows with the maximum 'numest' for each firm-year
idx = ibes_data_annual.groupby(['ticker', 'fyear'])['numest'].idxmax()

# Use the indices to create the deduplicated DataFrame
ibes_data_annual_unique = ibes_data_annual.loc[idx.reset_index(drop=True)]

# Display the first few rows of the deduplicated dataset
ibes_data_annual_unique.head()
# Out:
#    ticker    fpedats anndats_act  meanest  numest  stdev  actual  prcc_f  \
# 80     AA 2012-06-30  2012-07-09     0.33    19.0   0.14    0.18     NaN
# 80   CDTX 2016-03-31  2016-05-12   -16.00     4.0   1.12  -14.20   17.16
# 80   EXPD 2013-12-31  2014-02-25     1.87    21.0   0.09    1.68   44.25
# 80   JJSF 2009-09-30  2009-11-03     0.67     2.0   0.02    0.79   43.19
# 80    NSM 2009-05-31  2009-06-11     1.65     1.0    NaN    0.31     NaN
#
#      fyear
# 80  2011.0
# 80  2015.0
# 80  2013.0
# 80  2009.0
# 80  2008.0

# %%
ibes_data_annual_unique.
# Out:
# ((155668, 9), (3111534, 9))

# %%
ibes_data_annual[(ibes_data_annual['ticker'] == 'EXPD') & (ibes_data_annual['fyear'] == 2013)]
# Out:
#     ticker    fpedats anndats_act  meanest  numest  stdev  actual  prcc_f  \
# 34    EXPD 2013-12-31  2014-02-25     1.81    23.0   0.09    1.68   44.25
# 35    EXPD 2013-12-31  2014-02-25     1.81    23.0   0.09    1.68   44.25
# 36    EXPD 2013-12-31  2014-02-25     1.80    23.0   0.08    1.68   44.25
# 37    EXPD 2013-12-31  2014-02-25     1.80    23.0   0.08    1.68   44.25
# 38    EXPD 2013-12-31  2014-02-25     1.76    23.0   0.05    1.68   44.25
# ..     ...        ...         ...      ...     ...    ...     ...     ...
# 747   EXPD 2014-09-30  2014-11-04     0.52    14.0   0.02    0.53   44.25
# 748   EXPD 2014-09-30  2014-11-04     0.52    16.0   0.02    0.53   44.25
# 749   EXPD 2014-09-30  2014-11-04     0.52    16.0   0.02    0.53   44.25
# 750   EXPD 2014-09-30  2014-11-04     0.52    15.0   0.02    0.53   44.25
# 751   EXPD 2014-09-30  2014-11-04     0.52    15.0   0.02    0.53   44.25
#
#       fyear
# 34   2013.0
# 35   2013.0
# 36   2013.0
# 37   2013.0
# 38   2013.0
# ..      ...
# 747  2013.0
# 748  2013.0
# 749  2013.0
# 750  2013.0
# 751  2013.0
#
# [208 rows x 9 columns]

# %%
ibes_data_annual_unique[ibes_data_annual_unique[['ticker', 'fyear']].duplicated()]
# Out:
#        ticker    fpedats anndats_act  meanest  numest  stdev  actual  prcc_f  \
# 9        EXPD 2013-12-31  2014-02-25     1.96     1.0    NaN    1.68   44.25
# 10       JJSF 2010-03-31  2010-04-22     0.46     3.0   0.03    0.48   43.19
# 11        NSM 2009-05-31  2009-06-11    -0.42     7.0   0.02   -0.28     NaN
# 25        NSM 2010-08-31  2010-09-09     0.21    14.0   0.03    0.36     NaN
# 27        WGL 2016-06-30  2016-08-03     0.11     4.0   0.19    0.33   57.67
# ...       ...        ...         ...      ...     ...    ...     ...     ...
# 155663   FOSL 2006-09-30  2006-11-14     0.34     9.0   0.02    0.32   21.51
# 155664     LF 2010-03-31  2010-05-03    -0.29     5.0   0.04   -0.37    3.91
# 155665   OXPS 2006-12-31  2007-01-31     0.95     4.0   0.06    1.15   22.69
# 155666   STGN 2006-12-31  2007-03-06     0.40     2.0   0.03    0.25    7.44
# 155667   ZYNE 2016-12-31  2017-03-27    -2.59     8.0   0.12   -2.57   15.59
#
#          fyear  ANALYSTS  lnANALYSTS  DISPERSION  FCSTERROR
# 9       2013.0       1.0    0.693147         NaN   0.006328
# 10      2009.0       3.0    1.386294    0.000695   0.000463
# 11      2008.0       7.0    2.079442         NaN        NaN
# 25      2009.0      14.0    2.708050         NaN        NaN
# 27      2015.0       4.0    1.609438    0.003295   0.003815
# ...        ...       ...         ...         ...        ...
# 155663  2005.0       9.0    2.302585    0.000930   0.000930
# 155664  2009.0       5.0    1.791759    0.010230   0.020460
# 155665  2006.0       4.0    1.609438    0.002644   0.008814
# 155666  2006.0       2.0    1.098612    0.004032   0.020161
# 155667  2016.0       8.0    2.197225    0.007697   0.001283
#
# [130742 rows x 13 columns]

# %% [markdown]
# ## 2.2 Calculating the Annual Variables:
# 1. ANALYSTS (Annual): This is simply the number of analysts (numest) for the year.
# 2. DISPERSION (Annual):
# The standard deviation (stdev) of analysts' earnings per share forecasts divided by the price at the end of the fiscal year (prcc_f).
# 3. FCSTERROR (Annual):
# The forecast error is calculated as the absolute difference between the mean analyst EPS forecast (meanest) and the actual EPS (actual), divided by the price at the end of the fiscal year (prcc_f).

# %%
# Calculate the annual ANALYSTS variable (simply use numest)
ibes_data_annual_unique['ANALYSTS'] = ibes_data_annual_unique['numest']
ibes_data_annual_unique['lnANALYSTS'] = ibes_data_annual_unique['numest'].apply(lambda x: np.log(x + 1))

# Calculate the annual DISPERSION variable
ibes_data_annual_unique['DISPERSION'] = ibes_data_annual_unique['stdev'] / ibes_data_annual_unique['prcc_f']

# Calculate the annual FCSTERROR variable
ibes_data_annual_unique['FCSTERROR'] = abs(ibes_data_annual_unique['meanest'] - ibes_data_annual_unique['actual']) / ibes_data_annual_unique['prcc_f']

# Display the first few rows with the calculated variables
ibes_data_annual_unique[['ticker', 'fyear', 'ANALYSTS', 'DISPERSION', 'FCSTERROR']].head()
# Out:
#    ticker   fyear  ANALYSTS  DISPERSION  FCSTERROR
# 80     AA  2011.0      19.0         NaN        NaN
# 80   CDTX  2015.0       4.0    0.065268   0.104895
# 80   EXPD  2013.0      21.0    0.002034   0.004294
# 80   JJSF  2009.0       2.0    0.000463   0.002778
# 80    NSM  2008.0       1.0         NaN        NaN

# %%
ibes_data_group = ibes_data_annual_unique.groupby(['ticker', 'fyear'])
analyst = ibes_data_group['ANALYSTS'].max()
lnanalyst = ibes_data_group['lnANALYSTS'].max()
dispersion = ibes_data_group['DISPERSION'].mean()
fcsterror = ibes_data_group['FCSTERROR'].mean()

ibes_result = pd.merge(analyst, lnanalyst, left_index=True, right_index=True).merge(dispersion, left_index=True, right_index=True).merge(fcsterror, left_index=True, right_index=True).reset_index(drop=False)

# %%
ibes_result.to_pickle(os.path.join(const.TEMP_PATH, '20241006_analysts_dispersion_fcsterror.pkl'))

# %% [markdown]
# # Calculate Synchronicity

# %%
import os

import pandas as pd
import numpy as np
import statsmodels.api as sm

from Constants import Constants as const

# %%
data_path = r'D:\Users\wangy\Documents\data'

# Load the CRSP data
data = pd.read_csv(os.path.join(data_path, '20010101_20161231_crsp_stock_return.zip'))

# Convert date to datetime and sort by PERMNO and date
data['date'] = pd.to_datetime(data['date'])
data = data.sort_values(by=['PERMNO', 'date'])
# Out:
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\266846388.py:4: DtypeWarning: Columns (2,3,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join(data_path, '20010101_20161231_crsp_stock_return.zip'))

# %%
data.keys()
# Out:
# Index(['PERMNO', 'date', 'SICCD', 'NCUSIP', 'TICKER', 'PERMCO', 'HSICCD',
#        'CUSIP', 'RET', 'vwretd'],
#       dtype='object')

# %%
# Load the Fama-French industry classification data
industry_returns = pd.read_csv(os.path.join(data_path, '48_Industry_Portfolios_Daily.csv'))
industry_returns['Date'] = pd.to_datetime(industry_returns['Date'], format='%Y%m%d')

# %%
data['HSICCD'].replace('Z', np.nan, inplace=True)
data['HSICCD'] = data['HSICCD'].fillna(data['SICCD'].replace('Z', np.nan))
data = data[data['HSICCD'].notnull()]
# Out:
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1985788902.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['HSICCD'].replace('Z', np.nan, inplace=True)

# %%
data['HSICCD'] = data['HSICCD'].astype(int)

# Apply the mapping to the CRSP data
data['fama_french_industry'] = data['HSICCD'].apply(get_fama_french_industry)

# %% [markdown]
# ## Calculate Daily Synchronicity

# %%
# Convert daily returns to monthly returns (assuming 'RET' is the daily return)
data['RET'] = pd.to_numeric(data['RET'], errors='coerce')

# Prepare the market and industry return variables
# Assuming 'vwretd' is the value-weighted market return and industry_returns contains daily industry returns
industry_returns = industry_returns.melt(id_vars=['Date'], var_name='Industry', value_name='Industry_Return')
industry_returns['date'] = pd.to_datetime(industry_returns['Date'])

data = pd.merge(data, industry_returns, left_on=['date', 'fama_french_industry'], right_on=['date', 'Industry'], how='left')

# %%
data.head()
# Out:
#    PERMNO       date SICCD TICKER  PERMCO  HSICCD     CUSIP  HSICMG  HSICIG  \
# 0   10001 2007-01-03  4920   EWST    7953    4925  36720410     NaN     NaN
# 1   10001 2007-01-04  4920   EWST    7953    4925  36720410     NaN     NaN
# 2   10001 2007-01-05  4920   EWST    7953    4925  36720410     NaN     NaN
# 3   10001 2007-01-08  4920   EWST    7953    4925  36720410     NaN     NaN
# 4   10001 2007-01-09  4920   EWST    7953    4925  36720410     NaN     NaN
#
#       PRC       RET    vwretd    vwretx    ewretd    ewretx    sprtrn  \
# 0  11.100  0.000000 -0.001338 -0.001502 -0.000159 -0.000273 -0.001199
# 1  11.360  0.023423  0.000549  0.000546  0.000591  0.000575  0.001228
# 2  11.250 -0.009683 -0.007297 -0.007302 -0.009809 -0.009830 -0.006085
# 3 -11.345  0.008444  0.002568  0.002355  0.001731  0.001693  0.002220
# 4  11.240 -0.009255  0.000006  0.000005  0.000262  0.000260 -0.000517
#
#   fama_french_industry       Date Industry  Industry_Return
# 0                 Util 2007-01-03     Util             0.31
# 1                 Util 2007-01-04     Util            -0.23
# 2                 Util 2007-01-05     Util            -1.69
# 3                 Util 2007-01-08     Util            -0.02
# 4                 Util 2007-01-09     Util             0.21

# %%
# Drop rows with NaN values in relevant columns
data = data.dropna(subset=['RET', 'vwretd', 'Industry_Return'])

firm_daily_data = data[['PERMNO', 'date', 'RET', 'vwretd', 'Industry_Return']].drop_duplicates(subset=['PERMNO', 'date'], keep='last')

# %%
def calculate_daily_synchrony(group, mkt_only=False, ind_only=False):
    dep_var = 'RET'
    if mkt_only:
        if ind_only:
            raise ValueError('Only one of mkt_only and ind_only should be True')
        ind_vars = ['rm_t-1', 'vwretd', 'rm_t+1']
        suffix = '_MKT'
    elif ind_only:
        ind_vars = ['ri_t-1', 'Industry_Return', 'ri_t+1']
        suffix = '_IND'
    else:
        ind_vars = ['rm_t-1', 'ri_t-1', 'vwretd', 'Industry_Return', 'rm_t+1', 'ri_t+1']
        suffix = ''
        
    
    # Shift the independent variables to match the lag/lead structure as per equation (4)
    group['rm_t-1'] = group['vwretd'].shift(1)
    group['ri_t-1'] = group['Industry_Return'].shift(1)
    group['rm_t+1'] = group['vwretd'].shift(-1)
    group['ri_t+1'] = group['Industry_Return'].shift(-1)
    
    all_vars = [dep_var]
    all_vars.extend(ind_vars)

    # Drop rows with NaN values after shifting
    group = group.dropna(subset=all_vars, how='any')

    # Define the dependent and independent variables
    y = group[dep_var]
    X = group[ind_vars]
    X = sm.add_constant(X)  # Add a constant term to the regression

    try:
        # Run the regression
        model = sm.OLS(y, X, missing='drop').fit()
        r_squared = model.rsquared

        # Calculate IDIOSYN and SYNCHRONICITY
        synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan

    except Exception as e:
        # If regression fails for any reason, return NaN
        synchrony = np.nan

    return pd.Series({f'SYNCHRONICITY{suffix}_D': synchrony})

# %%
firm_daily_data['year'] = firm_daily_data['date'].dt.year
synchrony = firm_daily_data.groupby(['PERMNO', 'year']).apply(calculate_daily_synchrony).reset_index()
synchrony_ind = firm_daily_data.groupby(['PERMNO', 'year']).apply(calculate_daily_synchrony, ind_only=True).reset_index()
synchrony_mkt = firm_daily_data.groupby(['PERMNO', 'year']).apply(calculate_daily_synchrony, mkt_only=True).reset_index()
# Out:
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\936205773.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   synchrony = firm_daily_data.groupby(['PERMNO', 'year']).apply(calculate_daily_synchrony).reset_index()
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\936205773.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   synchrony_ind = firm_daily_data.groupby(['PERMNO', 'year']).apply(calculate_daily_synchrony, ind_only=True).reset_index()
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\1929752185.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# C:\Users\wangy\AppData\Local\Temp\ipykernel_17360\936205773.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   synchrony_mkt = firm_daily_data.groupby(['PERMNO', 'year']).apply(calculate_daily_synchrony, mkt_only=True).reset_index()

# %%
synchrony_daily_df = synchrony.merge(synchrony_mkt, on=['PERMNO', 'year'], how='left').merge(synchrony_ind, on=['PERMNO', 'year'], how='left')
synchrony_daily_df.to_pickle(os.path.join(const.TEMP_PATH, '20241010_synchrony_daily.pkl'))

# %%
synchrony_daily_df
# Out:
#        PERMNO  year  SYNCHRONICITY_D  SYNCHRONICITY_MKT_D  SYNCHRONICITY_IND_D
# 0       10001  2007        -3.570597            -3.726721            -3.744804
# 1       10001  2008        -1.987838            -2.048408            -2.313745
# 2       10001  2009        -3.654655            -3.772627            -3.809139
# 3       10001  2010        -3.342663            -3.539507            -3.814449
# 4       10001  2011        -1.980258            -2.225460            -2.083134
# ...       ...   ...              ...                  ...                  ...
# 73249   93436  2012        -1.395741            -1.577335            -2.408018
# 73250   93436  2013        -2.845489            -3.157357            -4.179562
# 73251   93436  2014        -0.989619            -1.128658            -2.032239
# 73252   93436  2015        -1.214303            -1.261081            -1.650169
# 73253   93436  2016        -1.306593            -1.444810            -2.341020
#
# [73254 rows x 5 columns]

# %% [markdown]
# ## Calculate Monthly Synchronicity

# %%
# Convert daily returns to monthly returns (assuming 'RET' is the daily return)
data['RET'] = pd.to_numeric(data['RET'], errors='coerce')
data['month'] = data['date'].dt.to_period('M')
monthly_returns = data.groupby(['PERMNO', 'month'])['RET'].apply(lambda x: (1 + x).prod() - 1).reset_index()
monthly_returns.rename(columns={'RET': 'monthly_return'}, inplace=True)

# %%
# Merge monthly returns back with original data
data = pd.merge(data, monthly_returns, on=['PERMNO', 'month'], how='left')

# Drop rows with NaN monthly returns
data = data.dropna(subset=['monthly_return'])

# %%
# Prepare the market and industry return variables
# Assuming 'vwretd' is the value-weighted market return and industry_returns contains daily industry returns
industry_returns = industry_returns.melt(id_vars=['Date'], var_name='Industry', value_name='Industry_Return')
industry_returns['Date'] = pd.to_datetime(industry_returns['Date'])

# %%
# Convert industry returns to monthly level
industry_returns['month'] = industry_returns['Date'].dt.to_period('M')
industry_monthly_returns = industry_returns.groupby(['Industry', 'month'])['Industry_Return'].apply(lambda x: (1 + x).prod() - 1).reset_index()

# %%
# Convert market returns to weekly level
data['vwretd'] = pd.to_numeric(data['vwretd'], errors='coerce')
market_return = data[['vwretd', 'month', 'date']].drop_duplicates().sort_values(by='date', ascending=True)
monthly_market_returns = market_return.groupby('month')['vwretd'].apply(lambda x: (1 + x).prod() - 1).reset_index()
monthly_market_returns.rename(columns={'vwretd': 'monthly_market_return'}, inplace=True)

# %%
# Merge weekly market returns back with original data
data = pd.merge(data, monthly_market_returns, on='month', how='left')

# Merge CRSP data with weekly industry returns
data = pd.merge(data, industry_monthly_returns, left_on=['month', 'fama_french_industry'], right_on=['month', 'Industry'], how='left')

# Drop rows with NaN values in relevant columns
data = data.dropna(subset=['monthly_return', 'monthly_market_return', 'Industry_Return'])

# %%
firm_monthly_data = data[['PERMNO', 'month', 'date', 'monthly_return', 'monthly_market_return', 'Industry_Return']].drop_duplicates(subset=['PERMNO', 'month'], keep='last')

# %%
def calculate_monthly_synchrony(group, mkt_only=False, ind_only=False):
    dep_var = 'monthly_return'
    if mkt_only:
        if ind_only:
            raise ValueError('Only one of mkt_only and ind_only should be True')
        ind_vars = ['rm_t-1', 'monthly_market_return', 'rm_t+1']
        suffix = '_MKT'
    elif ind_only:
        ind_vars = ['ri_t-1', 'Industry_Return', 'ri_t+1']
        suffix = '_IND'
    else:
        ind_vars = ['rm_t-1', 'ri_t-1', 'monthly_market_return', 'Industry_Return', 'rm_t+1', 'ri_t+1']
        suffix = ''
        
    
    # Shift the independent variables to match the lag/lead structure as per equation (4)
    group['rm_t-1'] = group['monthly_market_return'].shift(1)
    group['ri_t-1'] = group['Industry_Return'].shift(1)
    group['rm_t+1'] = group['monthly_market_return'].shift(-1)
    group['ri_t+1'] = group['Industry_Return'].shift(-1)
    
    all_vars = [dep_var]
    all_vars.extend(ind_vars)

    # Drop rows with NaN values after shifting
    group = group.dropna(subset=all_vars, how='any')

    # Define the dependent and independent variables
    y = group[dep_var]
    X = group[ind_vars]
    X = sm.add_constant(X)  # Add a constant term to the regression

    try:
        # Run the regression
        model = sm.OLS(y, X, missing='drop').fit()
        r_squared = model.rsquared

        # Calculate IDIOSYN and SYNCHRONICITY
        synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan

    except Exception as e:
        # If regression fails for any reason, return NaN
        synchrony = np.nan

    return pd.Series({f'SYNCHRONICITY{suffix}': synchrony})

# %%
firm_monthly_data['year'] = firm_monthly_data['date'].dt.year
synchrony = firm_monthly_data.groupby(['PERMNO', 'year']).apply(calculate_monthly_synchrony).reset_index()
synchrony_ind = firm_monthly_data.groupby(['PERMNO', 'year']).apply(calculate_monthly_synchrony, ind_only=True).reset_index()
synchrony_mkt = firm_monthly_data.groupby(['PERMNO', 'year']).apply(calculate_monthly_synchrony, mkt_only=True).reset_index()
# Out:
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# ...
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# D:\anaconda3\envs\finnlp\Lib\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\1207403954.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   synchrony = np.log(r_squared / (1 - r_squared)) if r_squared < 1 else np.nan
# C:\Users\wangy\AppData\Local\Temp\ipykernel_2496\472282081.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   synchrony_mkt = firm_monthly_data.groupby(['PERMNO', 'year']).apply(calculate_monthly_synchrony, mkt_only=True).reset_index()

# %%
synchrony_monthly_df = synchrony.merge(synchrony_mkt, on=['PERMNO', 'year'], how='left').merge(synchrony_ind, on=['PERMNO', 'year'], how='left')
synchrony_monthly_df.to_pickle(os.path.join(const.TEMP_PATH, '20250712_synchrony_monthly.pkl'))

# %%
synchrony_monthly_df = pd.read_pickle(os.path.join(const.TEMP_PATH, '20241010_synchrony_monthly.pkl'))

# %%
synchrony_monthly_df.keys()
# Out:
# Index(['PERMNO', 'year', 'SYNCHRONICITY', 'SYNCHRONICITY_MKT',
#        'SYNCHRONICITY_IND'],
#       dtype='object')

# %%
synchrony_monthly_df[synchrony_monthly_df['PERMNO'] == 10517]
# Out:
#      PERMNO  year  SYNCHRONICITY  SYNCHRONICITY_MKT  SYNCHRONICITY_IND
# 594   10517  2007       0.153897          -1.959758          -1.560775
# 595   10517  2008       1.395746           0.523615          -0.834738
# 596   10517  2009       3.511385          -0.512097           2.038146
# 597   10517  2010       2.861150           1.365538          -1.058951
# 598   10517  2011       0.214843          -0.946937          -0.360656
# 599   10517  2012       0.838720          -5.706510          -1.607901
# 600   10517  2013       1.697661           0.330381          -1.253293
# 601   10517  2014       1.478653           0.548072          -1.686310
# 602   10517  2015      -0.501928          -0.851317          -2.024815
# 603   10517  2016       0.888128          -0.026439          -0.155693

# %% [markdown]
# ### Calculate monthly variables

# %%
monthly_returns['year'] = monthly_returns['month'].dt.year

# %%
data.head()
# Out:
#    PERMNO       date SICCD TICKER  PERMCO HSICCD     CUSIP  HSICMG  HSICIG  \
# 0   10001 2007-01-03  4920   EWST    7953   4925  36720410     NaN     NaN
# 1   10001 2007-01-04  4920   EWST    7953   4925  36720410     NaN     NaN
# 2   10001 2007-01-05  4920   EWST    7953   4925  36720410     NaN     NaN
# 3   10001 2007-01-08  4920   EWST    7953   4925  36720410     NaN     NaN
# 4   10001 2007-01-09  4920   EWST    7953   4925  36720410     NaN     NaN
#
#       PRC        RET    vwretd    vwretx    ewretd    ewretx    sprtrn
# 0  11.100   0.000000 -0.001338 -0.001502 -0.000159 -0.000273 -0.001199
# 1  11.360   0.023423  0.000549  0.000546  0.000591  0.000575  0.001228
# 2  11.250  -0.009683 -0.007297 -0.007302 -0.009809 -0.009830 -0.006085
# 3 -11.345   0.008444  0.002568  0.002355  0.001731  0.001693  0.002220
# 4  11.240  -0.009255  0.000006  0.000005  0.000262  0.000260 -0.000517

# %%
test_df = data[(data['PERMNO'] == 14276) & (data['date'].dt.year == 2010)].copy()
test_df.head()
# Out:
# Empty DataFrame
# Columns: [PERMNO, date, SICCD, TICKER, PERMCO, HSICCD, CUSIP, HSICMG, HSICIG, PRC, RET, vwretd, vwretx, ewretd, ewretx, sprtrn, fama_french_industry, month, monthly_return, monthly_market_return, Industry, Industry_Return]
# Index: []
#
# [0 rows x 22 columns]

# %%
synchrony_monthly_df[(synchrony_monthly_df['PERMNO'] == 20626)]
# Out:
#        PERMNO  year  SYNCHRONICITY  SYNCHRONICITY_MKT  SYNCHRONICITY_IND
# 14682   20626  2007       0.292833          -1.204022          -1.080456
# 14683   20626  2008       4.180854           1.109165           1.189116
# 14684   20626  2009       4.856123           1.099743           1.520564
# 14685   20626  2010       3.446621           2.508349          -0.466792
# 14686   20626  2011       2.617086           2.331971           0.165084
# 14687   20626  2012       0.821894          -0.225859          -1.837376
# 14688   20626  2013       1.811536          -0.932521           1.502824
# 14689   20626  2014       0.776071          -1.281210          -0.208873
# 14690   20626  2015       2.854316           1.365893           0.735942
# 14691   20626  2016       2.235017           0.300790          -1.406803

# %%
data[const.YEAR] = data['date'].dt.year

# %%
data['RET'] = pd.to_numeric(data['RET'], errors='coerce')
data.dropna(subset=['RET'], inplace=True)
# Out:
# C:\Users\wangy\AppData\Local\Temp\ipykernel_19764\4276773977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RET'] = pd.to_numeric(data['RET'], errors='coerce')
# C:\Users\wangy\AppData\Local\Temp\ipykernel_19764\4276773977.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(subset=['RET'], inplace=True)

# %%
from scipy.stats import skew, kurtosis

daily_stat = data.groupby(['PERMNO', const.YEAR])['RET'].agg(
    sigma='std',
    skewness=skew,
    kurtosis=kurtosis
)

daily_stat.to_pickle(os.path.join(const.TEMP_PATH, '20250323_daily_stats.pkl'))
# Out:
# D:\Users\wangy\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:324: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   f = lambda x: func(x, *args, **kwargs)

# %%
from scipy.stats import skew, kurtosis

monthly_stat = monthly_returns.groupby(['PERMNO', 'year'])['monthly_return'].agg(
    sigma='std',
    skewness=skew,
    kurtosis=kurtosis
)

# %%
monthly_stat.to_pickle(os.path.join(const.TEMP_PATH, '20250316_monthly_stats.pkl'))

# %% [markdown]
# ## Calculate Weekly Synchronicity

# %%
# Convert daily returns to weekly returns (assuming 'RET' is the daily return)
data['RET'] = pd.to_numeric(data['RET'], errors='coerce')
data['week'] = data['date'].dt.to_period('W')
weekly_returns = data.groupby(['PERMNO', 'week'])['RET'].apply(lambda x: (1 + x).prod() - 1).reset_index()
weekly_returns.rename(columns={'RET': 'weekly_return'}, inplace=True)

# %%
# Merge weekly returns back with original data
data = pd.merge(data, weekly_returns, on=['PERMNO', 'week'], how='left')

# %%
# Drop rows with NaN weekly returns
data = data.dropna(subset=['weekly_return'])

# %%
# Prepare the market and industry return variables
# Assuming 'vwretd' is the value-weighted market return and industry_returns contains daily industry returns
industry_returns = industry_returns.melt(id_vars=['Date'], var_name='Industry', value_name='Industry_Return')
industry_returns['Date'] = pd.to_datetime(industry_returns['Date'])

# %%
# Convert industry returns to weekly level
industry_returns['week'] = industry_returns['Date'].dt.to_period('W')
industry_weekly_returns = industry_returns.groupby(['Industry', 'week'])['Industry_Return'].apply(lambda x: (1 + x).prod() - 1).reset_index()

# %%
industry_weekly_returns.head()
# Out:
#   Industry                   week  Industry_Return
# 0     Aero  1926-06-28/1926-07-04        -1.960000
# 1     Aero  1926-07-05/1926-07-11        -1.136270
# 2     Aero  1926-07-12/1926-07-18        -1.667164
# 3     Aero  1926-07-19/1926-07-25        -1.624224
# 4     Aero  1926-07-26/1926-08-01       -87.476932

# %%
# Convert market returns to weekly level
data['vwretd'] = pd.to_numeric(data['vwretd'], errors='coerce')
market_return = data[['vwretd', 'week', 'date']].drop_duplicates().sort_values(by='date', ascending=True)
weekly_market_returns = market_return.groupby('week')['vwretd'].apply(lambda x: (1 + x).prod() - 1).reset_index()
weekly_market_returns.rename(columns={'vwretd': 'weekly_market_return'}, inplace=True)

# %%
# Merge weekly market returns back with original data
data = pd.merge(data, weekly_market_returns, on='week', how='left')

# Merge CRSP data with weekly industry returns
data = pd.merge(data, industry_weekly_returns, left_on=['week', 'fama_french_industry'], right_on=['week', 'Industry'], how='left')

# %%
# Drop rows with NaN values in relevant columns
data = data.dropna(subset=['weekly_return', 'weekly_market_return', 'Industry_Return'])

# %%
firm_week_data = data[['PERMNO', 'week', 'date', 'weekly_return', 'weekly_market_return', 'Industry_Return']].drop_duplicates(subset=['PERMNO', 'week'], keep='last')

# %%
# Create firm-year level data
firm_week_data['year'] = firm_week_data['date'].dt.year

# %%
def calculate_synchrony(group):
    # Shift the independent variables to match the lag/lead structure as per equation (4)
    group['rm_t-1'] = group['weekly_market_return'].shift(1)
    group['ri_t-1'] = group['Industry_Return'].shift(1)
    group['rm_t+1'] = group['weekly_market_return'].shift(-1)
    group['ri_t+1'] = group['Industry_Return'].shift(-1)

    # Drop rows with NaN values after shifting
    group = group.dropna(subset=['weekly_return', 'rm_t-1', 'ri_t-1', 'weekly_market_return', 'Industry_Return', 'rm_t+1', 'ri_t+1'])

    # Define the dependent and independent variables
    y = group['weekly_return']
    X = group[['rm_t-1', 'ri_t-1', 'weekly_market_return', 'Industry_Return', 'rm_t+1', 'ri_t+1']]
    X = sm.add_constant(X)  # Add a constant term to the regression

    try:
        # Run the regression
        model = sm.OLS(y, X, missing='drop').fit()
        r_squared = model.rsquared

        # Calculate IDIOSYN and SYNCHRONICITY
        idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
        synchrony = -idiosyn if idiosyn is not np.nan else np.nan

    except Exception as e:
        # If regression fails for any reason, return NaN
        synchrony = np.nan

    return pd.Series({'SYNCHRONICITY': synchrony})

# %%
def calculate_synchrony_mkt(group):
    # Shift the independent variables to match the lag/lead structure as per equation (4)
    group['rm_t-1'] = group['weekly_market_return'].shift(1)
    group['rm_t+1'] = group['weekly_market_return'].shift(-1)

    # Drop rows with NaN values after shifting
    group = group.dropna(subset=['weekly_return', 'rm_t-1', 'weekly_market_return', 'rm_t+1'])

    # Define the dependent and independent variables
    y = group['weekly_return']
    X = group[['rm_t-1', 'weekly_market_return', 'rm_t+1']]
    X = sm.add_constant(X)  # Add a constant term to the regression

    try:
        # Run the regression
        model = sm.OLS(y, X, missing='drop').fit()
        r_squared = model.rsquared

        # Calculate IDIOSYN and SYNCHRONICITY
        idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
        synchrony = -idiosyn if idiosyn is not np.nan else np.nan

    except Exception as e:
        # If regression fails for any reason, return NaN
        synchrony = np.nan

    return pd.Series({'SYNCHRONICITY_MKT': synchrony})

# %%
def calculate_synchrony_ind(group):
    # Shift the independent variables to match the lag/lead structure as per equation (4)
    group['ri_t-1'] = group['Industry_Return'].shift(1)
    group['ri_t+1'] = group['Industry_Return'].shift(-1)

    # Drop rows with NaN values after shifting
    group = group.dropna(subset=['weekly_return', 'ri_t-1', 'Industry_Return',  'ri_t+1'])

    # Define the dependent and independent variables
    y = group['weekly_return']
    X = group[['ri_t-1', 'Industry_Return', 'ri_t+1']]
    X = sm.add_constant(X)  # Add a constant term to the regression

    try:
        # Run the regression
        model = sm.OLS(y, X, missing='drop').fit()
        r_squared = model.rsquared

        # Calculate IDIOSYN and SYNCHRONICITY
        idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
        synchrony = -idiosyn if idiosyn is not np.nan else np.nan

    except Exception as e:
        # If regression fails for any reason, return NaN
        synchrony = np.nan

    return pd.Series({'SYNCHRONICITY_IND': synchrony})

# %%
synchrony = firm_week_data.groupby(['PERMNO', 'year']).apply(calculate_synchrony).reset_index()
# Out:
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
# ...
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1138875461.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\496929731.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   synchrony = firm_week_data.groupby(['PERMNO', 'year']).apply(calculate_synchrony).reset_index()

# %%
synchrony_ind = firm_week_data.groupby(['PERMNO', 'year']).apply(calculate_synchrony_ind).reset_index()
synchrony_mkt = firm_week_data.groupby(['PERMNO', 'year']).apply(calculate_synchrony_mkt).reset_index()
# Out:
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2965441181.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# ...
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\1675897918.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   idiosyn = np.log((1 - r_squared) / r_squared) if r_squared < 1 else np.nan
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# D:\Users\wangy\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\wangy\AppData\Local\Temp\ipykernel_21048\2625616080.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   synchrony_mkt = firm_week_data.groupby(['PERMNO', 'year']).apply(calculate_synchrony_mkt).reset_index()

# %%
synchrony_df = synchrony.merge(synchrony_mkt, on=['PERMNO', 'year'], how='left').merge(synchrony_ind, on=['PERMNO', 'year'], how='left')

# %%
link_file = data[['PERMNO', 'TICKER']].drop_duplicates(subset=['PERMNO'])
synchrony_df_ticker = synchrony_df.merge(link_file, on=['PERMNO'], how='left')
synchrony_df_ticker.to_pickle(os.path.join(const.TEMP_PATH, '20241006_synchrony_weekly.pkl'))

# %%
data.columns
# Out:
# Index(['PERMNO', 'date', 'SICCD', 'TICKER', 'PERMCO', 'HSICCD', 'CUSIP',
#        'HSICMG', 'HSICIG', 'PRC', 'RET', 'vwretd', 'vwretx', 'ewretd',
#        'ewretx', 'sprtrn', 'fama_french_industry', 'week', 'weekly_return',
#        'weekly_market_return', 'Industry', 'Industry_Return'],
#       dtype='object')

# %% [markdown]
# # Test WRDS available data

# %%
# 连接 WRDS
db = wrds.Connection(wrds_username='wangyouan')
# Out:
# WRDS recommends setting up a .pgpass file.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
# 获取所有库
libraries = db.list_libraries()

print("\n📚 检查有权限访问的 WRDS 数据库...\n")

# 遍历所有库，尝试列出表
for lib in libraries:
    try:
        datasets = db.list_tables(library=lib)
        if datasets:
            print(f"✅ {lib} ({len(datasets)} datasets):")
            for table in datasets[:10]:  # 如果想全部打印可以删掉 [:10]
                print(f"   - {table}")
            if len(datasets) > 10:
                print(f"   ... ({len(datasets)-10} more tables)\n")
            else:
                print()
    except Exception as e:
        # 没有权限或者其他错误
        pass
# Out:
# WRDS recommends setting up a .pgpass file.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done
#
# 📚 检查有权限访问的 WRDS 数据库...
#
# ✅ aha_sample (1 datasets):
#    - annual_survey
#
# ✅ ahasamp (1 datasets):
#    - annual_survey
#
# ✅ auditsmp (15 datasets):
#    - accfiler
#    - auditcblock
#    - auditchange
#    - auditfees
#    - auditfeesr
#    - auditnonreli
#    - auditopin
#    - auditors
#    - auditorsinfo
#    - auditsox302
#    ... (5 more tables)
#
# ✅ auditsmp_all (15 datasets):
#    - accfiler
#    - auditcblock
#    - auditchange
#    - auditfees
#    - auditfeesr
#    - auditnonreli
#    - auditopin
#    - auditors
#    - auditorsinfo
#    - auditsox302
#    ... (5 more tables)
#
# ✅ bank (43 datasets):
#    - _banknames_
#    - _leinames_
#    - bic_to_lei
#    - idrssd_to_lei
#    - isin_to_lei
#    - lei_legalevents
#    - lei_main
#    - lei_otheraddresses
#    - lei_otherentnames
#    - lei_successorentity
#    ... (33 more tables)
#
# ✅ bank_all (21 datasets):
#    - wrds_bank_crsp_link
#    - wrds_bank_reg_vars
#    - wrds_call_rcfa_1
#    - wrds_call_rcfd_1
#    - wrds_call_rcfd_2
#    - wrds_call_rcfn_1
#    - wrds_call_rcfw_1
#    - wrds_call_rcoa_1
#    - wrds_call_rcon_1
#    - wrds_call_rcon_2
#    ... (11 more tables)
#
# ✅ bank_premium_samp (9 datasets):
#    - bic_to_lei
#    - idrssd_to_lei
#    - isin_to_lei
#    - lei_main
#    - rel_main
#    - wrds_call_derived
#    - wrds_call_frgn_rcfd
#    - wrds_call_research
#    - wrds_struct_rel_ultimate
#
# ✅ banksamp (9 datasets):
#    - bic_to_lei
#    - idrssd_to_lei
#    - isin_to_lei
#    - lei_main
#    - rel_main
#    - wrds_call_derived
#    - wrds_call_frgn_rcfd
#    - wrds_call_research
#    - wrds_struct_rel_ultimate
#
# ✅ block (3 datasets):
#    - block
#    - block2
#    - blockw
#
# ✅ block_all (3 datasets):
#    - block
#    - block2
#    - blockw
#
# ✅ boardex_trial (40 datasets):
#    - jr_board_characteristics
#    - jr_board_dir_announcements
#    - jr_board_dir_committees
#    - jr_board_education_assoc
#    - jr_board_listed_assoc
#    - jr_board_nfp_assoc
#    - jr_board_other_assoc
#    - jr_board_unlisted_assoc
#    - jr_company_profile_advisors
#    - jr_company_profile_details
#    ... (30 more tables)
#
# ✅ boardsmp (40 datasets):
#    - jr_board_characteristics
#    - jr_board_dir_announcements
#    - jr_board_dir_committees
#    - jr_board_education_assoc
#    - jr_board_listed_assoc
#    - jr_board_nfp_assoc
#    - jr_board_other_assoc
#    - jr_board_unlisted_assoc
#    - jr_company_profile_advisors
#    - jr_company_profile_details
#    ... (30 more tables)
#
# ✅ bvd_amadeus_trial (3 datasets):
#    - amadeus_qvards
#    - trial_amadeus_financials_v
#    - trial_amadeus_v
#
# ✅ bvd_bvdbankf_trial (6 datasets):
#    - bvdbankf_bank
#    - bvdbankf_financials
#    - bvdbankf_ish_guo_duo
#    - bvdbankf_qvards
#    - bvdbankf_stock_annual
#    - bvdbankf_subsidiaries
#
# ✅ bvd_orbis_trial (9 datasets):
#    - ob_all_cur_shh_1st_level_lms
#    - ob_all_subs_first_level_lms
#    - ob_banks_g_fins_usd_int_lms
#    - ob_banks_g_fins_usd_lms
#    - ob_ins_g_fins_usd_lms
#    - ob_w_company_id_table_lms
#    - ob_w_ind_g_fins_cfl_usd_int_lms
#    - ob_w_ind_g_fins_cfl_usd_lms
#    - orbis_qvards
#
# ✅ bvdsamp (18 datasets):
#    - amadeus_qvards
#    - bvdbankf_bank
#    - bvdbankf_financials
#    - bvdbankf_ish_guo_duo
#    - bvdbankf_qvards
#    - bvdbankf_stock_annual
#    - bvdbankf_subsidiaries
#    - ob_all_cur_shh_1st_level_lms
#    - ob_all_subs_first_level_lms
#    - ob_banks_g_fins_usd_int_lms
#    ... (8 more tables)
#
# ✅ calcbench_trial (3 datasets):
#    - breakout
#    - entity_names
#    - normalized_fn
#
# ✅ calcbnch (25 datasets):
#    - accounts_payable_fn
#    - accounts_receivable_fn
#    - breakout
#    - business_combinations_fn
#    - capitalized_leases_fn
#    - commitments_contingencies_fn
#    - derivatives_hedging_bo
#    - derivatives_hedging_fn
#    - entity_names
#    - equity_based_compensation_bo
#    ... (15 more tables)
#
# ✅ cboe (86 datasets):
#    - cboe
#    - deltanumber
#    - eqfactor
#    - eqhvol
#    - eqhvolmap
#    - eqmaster
#    - eqprice
#    - eqsplitdiv
#    - eqsplitdivsupp
#    - eqsplitdivtype
#    ... (76 more tables)
#
# ✅ cboe_all (1 datasets):
#    - cboe
#
# ✅ cboe_sample (6 datasets):
#    - eqhvol
#    - eqmaster
#    - eqprice
#    - ivlisted
#    - optprice
#    - wrds_eq_opt_merged
#
# ✅ cboesamp (6 datasets):
#    - eqhvol
#    - eqmaster
#    - eqprice
#    - ivlisted
#    - optprice
#    - wrds_eq_opt_merged
#
# ✅ ciqsamp (36 datasets):
#    - chars
#    - ciqkeydev
#    - ratings_ids_trial
#    - wrds_cik_trial
#    - wrds_compensation_trial
#    - wrds_compensationdetails_trial
#    - wrds_cusip_trial
#    - wrds_debt_trial
#    - wrds_eassessment_trial
#    - wrds_entity_info_trial
#    ... (26 more tables)
#
# ✅ ciqsamp_capstrct (2 datasets):
#    - wrds_debt_trial
#    - wrds_equity_trial
#
# ✅ ciqsamp_common (6 datasets):
#    - chars
#    - wrds_cik_trial
#    - wrds_cusip_trial
#    - wrds_gvkey_trial
#    - wrds_isin_trial
#    - wrds_ticker_trial
#
# ✅ ciqsamp_keydev (3 datasets):
#    - ciqkeydev
#    - wrds_keydev_div_trial
#    - wrds_keydev_trial
#
# ✅ ciqsamp_pplintel (11 datasets):
#    - wrds_cik_trial
#    - wrds_compensation_trial
#    - wrds_compensationdetails_trial
#    - wrds_cusip_trial
#    - wrds_debt_trial
#    - wrds_equity_trial
#    - wrds_gvkey_trial
#    - wrds_isin_trial
#    - wrds_keydev_trial
#    - wrds_professional_trial
#    ... (1 more tables)
#
# ✅ ciqsamp_ratings (9 datasets):
#    - ratings_ids_trial
#    - wrds_eassessment_trial
#    - wrds_entity_info_trial
#    - wrds_erating_trial
#    - wrds_inst_info_trial
#    - wrds_irating_trial
#    - wrds_sassessment_trial
#    - wrds_sec_info_trial
#    - wrds_srating_trial
#
# ✅ ciqsamp_transactions (11 datasets):
#    - wrds_offerings
#    - wrds_offerings_advisors
#    - wrds_offerings_feat
#    - wrds_offerings_proceeds
#    - wrds_offerings_registration
#    - wrds_offerings_rel
#    - wrds_trans_advisors
#    - wrds_trans_conditions
#    - wrds_trans_considerations
#    - wrds_trans_features
#    ... (1 more tables)
#
# ✅ ciqsamp_transcripts (2 datasets):
#    - wrds_transcript_detail
#    - wrds_transcript_person
#
# ✅ cisdmsmp (2 datasets):
#    - active_fund_info
#    - active_returns_assets
#
# ✅ columnar (5 datasets):
#    - chunk
#    - chunk_group
#    - options
#    - storage
#    - stripe
#
# ✅ comp (311 datasets):
#    - aco_amda
#    - aco_imda
#    - aco_indfnta
#    - aco_indfntq
#    - aco_indfntytd
#    - aco_indsta
#    - aco_indstq
#    - aco_indstytd
#    - aco_notesa
#    - aco_notesq
#    ... (301 more tables)
#
# ✅ comp_bank (20 datasets):
#    - bank_aacctchg
#    - bank_adesind
#    - bank_afnd1
#    - bank_afnd2
#    - bank_afnddc1
#    - bank_afnddc2
#    - bank_afntind
#    - bank_funda
#    - bank_funda_fncd
#    - bank_fundq
#    ... (10 more tables)
#
# ✅ comp_bank_daily (20 datasets):
#    - bank_aacctchg
#    - bank_adesind
#    - bank_afnd1
#    - bank_afnd2
#    - bank_afnddc1
#    - bank_afnddc2
#    - bank_afntind
#    - bank_funda
#    - bank_funda_fncd
#    - bank_fundq
#    ... (10 more tables)
#
# ✅ comp_global (115 datasets):
#    - dd_group
#    - dd_group_xref
#    - dd_item
#    - dd_package
#    - g_chars
#    - g_co_aaudit
#    - g_co_adesind
#    - g_co_afnd1
#    - g_co_afnd2
#    - g_co_afnddc1
#    ... (105 more tables)
#
# ✅ comp_global_daily (143 datasets):
#    - dd_group
#    - dd_group_xref
#    - dd_item
#    - dd_package
#    - g_bmiindex
#    - g_bmiindexdlynumvalue
#    - g_bmiindexidentifier
#    - g_bmiindexrel
#    - g_bmiindextradingitem
#    - g_chars
#    ... (133 more tables)
#
# ✅ comp_na_annual_all (201 datasets):
#    - aco_amda
#    - aco_imda
#    - aco_indfnta
#    - aco_indfntq
#    - aco_indfntytd
#    - aco_indsta
#    - aco_indstq
#    - aco_indstytd
#    - aco_notesa
#    - aco_notesq
#    ... (191 more tables)
#
# ✅ comp_na_daily_all (204 datasets):
#    - aco_amda
#    - aco_imda
#    - aco_indfnta
#    - aco_indfntq
#    - aco_indfntytd
#    - aco_indsta
#    - aco_indstq
#    - aco_indstytd
#    - aco_notesa
#    - aco_notesq
#    ... (194 more tables)
#
# ✅ comp_na_monthly_all (199 datasets):
#    - aco_amda
#    - aco_imda
#    - aco_indfnta
#    - aco_indfntq
#    - aco_indfntytd
#    - aco_indsta
#    - aco_indstq
#    - aco_indstytd
#    - aco_notesa
#    - aco_notesq
#    ... (189 more tables)
#
# ✅ comp_segments_hist (70 datasets):
#    - dd_group
#    - dd_group_xref
#    - dd_item
#    - dd_package
#    - names_seg
#    - r_accstd
#    - r_acqmeth
#    - r_auditors
#    - r_auopic
#    - r_balpres
#    ... (60 more tables)
#
# ✅ comp_segments_hist_daily (70 datasets):
#    - dd_group
#    - dd_group_xref
#    - dd_item
#    - dd_package
#    - names_seg
#    - r_accstd
#    - r_acqmeth
#    - r_auditors
#    - r_auopic
#    - r_balpres
#    ... (60 more tables)
#
# ✅ compa (201 datasets):
#    - aco_amda
#    - aco_imda
#    - aco_indfnta
#    - aco_indfntq
#    - aco_indfntytd
#    - aco_indsta
#    - aco_indstq
#    - aco_indstytd
#    - aco_notesa
#    - aco_notesq
#    ... (191 more tables)
#
# ✅ compb (20 datasets):
#    - bank_aacctchg
#    - bank_adesind
#    - bank_afnd1
#    - bank_afnd2
#    - bank_afnddc1
#    - bank_afnddc2
#    - bank_afntind
#    - bank_funda
#    - bank_funda_fncd
#    - bank_fundq
#    ... (10 more tables)
#
# ✅ compg (115 datasets):
#    - dd_group
#    - dd_group_xref
#    - dd_item
#    - dd_package
#    - g_chars
#    - g_co_aaudit
#    - g_co_adesind
#    - g_co_afnd1
#    - g_co_afnd2
#    - g_co_afnddc1
#    ... (105 more tables)
#
# ✅ compm (199 datasets):
#    - aco_amda
#    - aco_imda
#    - aco_indfnta
#    - aco_indfntq
#    - aco_indfntytd
#    - aco_indsta
#    - aco_indstq
#    - aco_indstytd
#    - aco_notesa
#    - aco_notesq
#    ... (189 more tables)
#
# ✅ compsamp (11 datasets):
#    - company
#    - compsamp
#    - funda
#    - funda_fncd
#    - fundq
#    - fundq_fncd
#    - names
#    - namesq
#    - secd
#    - secm
#    ... (1 more tables)
#
# ✅ compsamp_all (11 datasets):
#    - company
#    - compsamp
#    - funda
#    - funda_fncd
#    - fundq
#    - fundq_fncd
#    - names
#    - namesq
#    - secd
#    - secm
#    ... (1 more tables)
#
# ✅ compsamp_snapshot (10 datasets):
#    - chars
#    - wrds_cs_names
#    - wrds_csa_pit
#    - wrds_csa_pit_sorted
#    - wrds_csa_restated
#    - wrds_csa_unrestated
#    - wrds_csq_pit
#    - wrds_csq_pit_sorted
#    - wrds_csq_restated
#    - wrds_csq_unrestated
#
# ✅ compseg (70 datasets):
#    - dd_group
#    - dd_group_xref
#    - dd_item
#    - dd_package
#    - names_seg
#    - r_accstd
#    - r_acqmeth
#    - r_auditors
#    - r_auopic
#    - r_balpres
#    ... (60 more tables)
#
# ✅ contrib (31 datasets):
#    - _states_
#    - better_beta
#    - blocksv
#    - ceo_turnover
#    - char_returns
#    - cik_types
#    - classified_boards
#    - common_own_firm
#    - common_own_industry
#    - corp_culture
#    ... (21 more tables)
#
# ✅ contrib_as_filed_financials (5 datasets):
#    - funda_asfiled
#    - structure_asfiled
#    - tag_bs
#    - tag_cf
#    - tag_is
#
# ✅ contrib_char_returns (1 datasets):
#    - char_returns
#
# ✅ contrib_corporate_culture (1 datasets):
#    - corp_culture
#
# ✅ contrib_general (17 datasets):
#    - _states_
#    - better_beta
#    - blocksv
#    - ceo_turnover
#    - cik_types
#    - classified_boards
#    - common_own_firm
#    - common_own_industry
#    - dealscan_link_bs
#    - dealscan_link_comp
#    ... (7 more tables)
#
# ✅ contrib_global_factor (1 datasets):
#    - global_factor
#
# ✅ contrib_intangible_value (2 datasets):
#    - int_factors
#    - int_xsec
#
# ✅ contrib_kpss (2 datasets):
#    - kpss_patents
#    - kpss_permco_link
#
# ✅ contrib_liva (1 datasets):
#    - liva
#
# ✅ crsp (433 datasets):
#    - acti
#    - asia
#    - asib
#    - asic
#    - asio
#    - asix
#    - bmdebt
#    - bmheader
#    - bmpaymts
#    - bmquotes
#    ... (423 more tables)
#
# ✅ crsp_a_indexes (113 datasets):
#    - acti
#    - asia
#    - asib
#    - asic
#    - asio
#    - asix
#    - cs20yr
#    - cs5yr
#    - cs90d
#    - dport1
#    ... (103 more tables)
#
# ✅ crsp_a_stock (95 datasets):
#    - dse
#    - dseall
#    - dsedelist
#    - dsedist
#    - dseexchdates
#    - dsenames
#    - dsenasdin
#    - dseshares
#    - dsf
#    - dsf_v2
#    ... (85 more tables)
#
# ✅ crsp_a_treasuries (64 datasets):
#    - bmdebt
#    - bmheader
#    - bmpaymts
#    - bmquotes
#    - bmyield
#    - bndprt06
#    - bndprt12
#    - bxcalind
#    - bxdlyind
#    - bxmthind
#    ... (54 more tables)
#
# ✅ crspsamp (26 datasets):
#    - ccm_qvards
#    - ccmlinktable_trial
#    - ccmnames_trial
#    - ccmxpf_lnkhist
#    - comphead
#    - contact_info
#    - crspdsf
#    - crspmsf
#    - daily_nav_ret
#    - dividends
#    ... (16 more tables)
#
# ✅ crspsamp_all (10 datasets):
#    - ccm_qvards
#    - ccmlinktable_trial
#    - ccmnames_trial
#    - ccmxpf_lnkhist
#    - comphead
#    - crspdsf
#    - crspmsf
#    - dsenames_trial
#    - dsftrial
#    - msftrial
#
# ✅ crspsamp_mf (16 datasets):
#    - contact_info
#    - daily_nav_ret
#    - dividends
#    - front_load
#    - front_load_grp
#    - fund_fees
#    - fund_hdr_hist
#    - fund_names
#    - fund_style
#    - fund_summary
#    ... (6 more tables)
#
# ✅ csmar (267 datasets):
#    - af_actual
#    - af_anaforefeature
#    - af_analystprofile
#    - af_anarank
#    - af_anlystratingststic
#    - af_bench
#    - af_brokerageprofile
#    - af_cfeatureprofile
#    - af_co
#    - af_forecast
#    ... (257 more tables)
#
# ✅ csmar_af (13 datasets):
#    - af_actual
#    - af_anaforefeature
#    - af_analystprofile
#    - af_anarank
#    - af_anlystratingststic
#    - af_bench
#    - af_brokerageprofile
#    - af_cfeatureprofile
#    - af_co
#    - af_forecast
#    ... (3 more tables)
#
# ✅ csmar_cd (3 datasets):
#    - cd_compofdivprofitco
#    - cd_compofdivprofitind
#    - cd_dividend
#
# ✅ csmar_cg (24 datasets):
#    - cg_agm
#    - cg_bsmrcshd
#    - cg_capchg
#    - cg_ceo
#    - cg_chshhdeq
#    - cg_co
#    - cg_commissionsta
#    - cg_commit
#    - cg_csharehold
#    - cg_cxhy
#    ... (14 more tables)
#
# ✅ csmar_colc (9 datasets):
#    - colc_chgcoprinfo
#    - colc_co2stock
#    - colc_combas
#    - colc_comcfs
#    - colc_comins
#    - colc_coprinfo
#    - stk_colc_balance
#    - stk_colc_cashflow
#    - stk_colc_income
#
# ✅ csmar_financial (15 datasets):
#    - combas
#    - comins
#    - comscfd
#    - comscfi
#    - csmar_master
#    - fn_fn046
#    - forecdt
#    - fs_combas
#    - fs_comins
#    - fs_comscfd
#    ... (5 more tables)
#
# ✅ csmar_funds (67 datasets):
#    - fund_allocation
#    - fund_apprchgregi
#    - fund_approved
#    - fund_areaclass
#    - fund_classinfochange
#    - fund_constsec
#    - fund_custodian
#    - fund_etfmartra
#    - fund_feeschange
#    - fund_fin_balance
#    ... (57 more tables)
#
# ✅ csmar_hld (15 datasets):
#    - hld_capstru
#    - hld_chgequity
#    - hld_contrshr
#    - hld_copro
#    - hld_cr
#    - hld_fundhold
#    - hld_lock_shares
#    - hld_lockshares_detail
#    - hld_negcr
#    - hld_negshr
#    ... (5 more tables)
#
# ✅ csmar_ini (3 datasets):
#    - ini_holder_detail
#    - ini_holder_incrordesr
#    - ini_holdersystematics
#
# ✅ csmar_ipo_a (25 datasets):
#    - ipo_cobasic
#    - ipo_ipobalance
#    - ipo_ipobasic
#    - ipo_ipocashflow
#    - ipo_ipocg
#    - ipo_ipocsmne
#    - ipo_ipocsne
#    - ipo_ipoday
#    - ipo_ipoenfoc
#    - ipo_ipofin
#    ... (15 more tables)
#
# ✅ csmar_ma (14 datasets):
#    - stk_ma_assetreplace
#    - stk_ma_assetstopay
#    - stk_ma_assettrans
#    - stk_ma_cashpayment
#    - stk_ma_cdr
#    - stk_ma_equitytransfer
#    - stk_ma_involvedparty
#    - stk_ma_merger
#    - stk_ma_stockpayment
#    - stk_ma_tenderoffer
#    ... (4 more tables)
#
# ✅ csmar_rs (11 datasets):
#    - rs_aibasic
#    - rs_capc
#    - rs_cobasic
#    - rs_csne
#    - rs_exec
#    - rs_finan
#    - rs_profcast
#    - rs_robacdler
#    - rs_robasic
#    - rs_trbasic
#    ... (1 more tables)
#
# ✅ csmar_trade (68 datasets):
#    - csmar_t_adjustfactor
#    - csmar_t_bwardquotation
#    - csmar_t_bwardquotationmonth
#    - csmar_t_bwardquotationweek
#    - csmar_t_bwardquotationyear
#    - csmar_t_cale
#    - csmar_t_capchg
#    - csmar_t_cndalym
#    - csmar_t_cnmont
#    - csmar_t_co
#    ... (58 more tables)
#
# ✅ csmsamp_all (7 datasets):
#    - combas
#    - csmar_t_co
#    - csmar_t_dalyr
#    - csmar_t_mnth
#    - fund_maininfo
#    - wrds_ipo_basics
#    - wrds_stk_ma_trading
#
# ✅ djones (2 datasets):
#    - djdaily
#    - djmonthly
#
# ✅ djones_all (2 datasets):
#    - djdaily
#    - djmonthly
#
# ✅ dmef (4 datasets):
#    - setfour
#    - setone
#    - setthree
#    - settwo
#
# ✅ dmef_all (4 datasets):
#    - setfour
#    - setone
#    - setthree
#    - settwo
#
# ✅ doe (2 datasets):
#    - doe
#    - doenames
#
# ✅ doe_all (2 datasets):
#    - doe
#    - doenames
#
# ✅ etfg_samp (4 datasets):
#    - analytics
#    - constituents
#    - fund_flow
#    - industry
#
# ✅ etfgsamp (4 datasets):
#    - analytics
#    - constituents
#    - fund_flow
#    - industry
#
# ✅ factsamp_all (28 datasets):
#    - funds
#    - monthly_prices_final_int
#    - monthly_prices_final_int_sample
#    - monthly_prices_final_usc
#    - monthly_prices_final_usc_sample
#    - wrds_fund_af_int
#    - wrds_fund_af_int_sample
#    - wrds_fund_af_usc
#    - wrds_fund_af_usc_sample
#    - wrds_fund_ltm_int
#    ... (18 more tables)
#
# ✅ factsamp_revere (12 datasets):
#    - chars
#    - wrds_company
#    - wrds_company_hist
#    - wrds_company_segrev_detail
#    - wrds_company_segrev_report
#    - wrds_company_segrev_summary
#    - wrds_geo_exp
#    - wrds_geo_exp_all
#    - wrds_product_merged
#    - wrds_product_sector
#    ... (2 more tables)
#
# ✅ ff (12 datasets):
#    - factors_china
#    - factors_daily
#    - factors_monthly
#    - fivefactors_daily
#    - fivefactors_monthly
#    - industry12
#    - industry48
#    - liq_ps
#    - liq_sadka
#    - portfolios
#    ... (2 more tables)
#
# ✅ ff_all (12 datasets):
#    - factors_china
#    - factors_daily
#    - factors_monthly
#    - fivefactors_daily
#    - fivefactors_monthly
#    - industry12
#    - industry48
#    - liq_ps
#    - liq_sadka
#    - portfolios
#    ... (2 more tables)
#
# ✅ fisdsamp (9 datasets):
#    - fisd_issue_samp
#    - fisd_issuer_samp
#    - fisd_mergedissue_samp
#    - fisd_mergedissuer_samp
#    - fisd_mergedredemption_samp
#    - fisd_ratings_samp
#    - fisd_tsales_samp
#    - issue_issuer_samp
#    - naic_bond_transactions_samp
#
# ✅ fisdsamp_all (9 datasets):
#    - fisd_issue_samp
#    - fisd_issuer_samp
#    - fisd_mergedissue_samp
#    - fisd_mergedissuer_samp
#    - fisd_mergedredemption_samp
#    - fisd_ratings_samp
#    - fisd_tsales_samp
#    - issue_issuer_samp
#    - naic_bond_transactions_samp
#
# ✅ fjc (7 datasets):
#    - appeals
#    - bankruptcy
#    - civil
#    - criminal
#    - wrds_bankruptcy_link
#    - wrds_civil_link
#    - wrds_criminal_link
#
# ✅ fjc_linking (3 datasets):
#    - wrds_bankruptcy_link
#    - wrds_civil_link
#    - wrds_criminal_link
#
# ✅ fjc_litigation (4 datasets):
#    - appeals
#    - bankruptcy
#    - civil
#    - criminal
#
# ✅ frb (4 datasets):
#    - fx_daily
#    - fx_monthly
#    - rates_daily
#    - rates_monthly
#
# ✅ frb_all (4 datasets):
#    - fx_daily
#    - fx_monthly
#    - rates_daily
#    - rates_monthly
#
# ✅ fssamp (40 datasets):
#    - chars
#    - funds
#    - monthly_prices_final_int
#    - monthly_prices_final_int_sample
#    - monthly_prices_final_usc
#    - monthly_prices_final_usc_sample
#    - wrds_company
#    - wrds_company_hist
#    - wrds_company_segrev_detail
#    - wrds_company_segrev_report
#    ... (30 more tables)
#
# ✅ ftsesamp (3 datasets):
#    - ctr_monthly_us
#    - idx_holdings_us
#    - rgs_sw_us
#
# ✅ ftsesamp_russell_us (3 datasets):
#    - ctr_monthly_us
#    - idx_holdings_us
#    - rgs_sw_us
#
# ✅ gutenberg (1 datasets):
#    - gutenberg_book
#
# ✅ hfrsamp (7 datasets):
#    - asset
#    - fund
#    - hfri_const
#    - hfrx_const
#    - instrument
#    - region
#    - ror
#
# ✅ hfrsamp_hfrdb (7 datasets):
#    - asset
#    - fund
#    - hfri_const
#    - hfrx_const
#    - instrument
#    - region
#    - ror
#
# ✅ ibessamp_kpi (9 datasets):
#    - act_kpiint
#    - act_kpius
#    - chars
#    - companies
#    - det_kpiint
#    - det_kpius
#    - measures
#    - statsum_kpiint
#    - statsum_kpius
#
# ✅ ifgrsamp (4 datasets):
#    - abi_ticker_map
#    - business
#    - business_chars
#    - residential
#
# ✅ ims_obp_trial (2 datasets):
#    - chars
#    - obp_premium
#
# ✅ imssamp (2 datasets):
#    - chars
#    - obp_premium
#
# ✅ infogroupsamp_business (3 datasets):
#    - abi_ticker_map
#    - business
#    - business_chars
#
# ✅ infogroupsamp_residential (1 datasets):
#    - residential
#
# ✅ insdsamp (15 datasets):
#    - fdic_derivatives
#    - fdic_document_info
#    - fdic_footnotes
#    - fdic_nonderivatives
#    - fdic_reporting_owners
#    - fdic_signatures
#    - sec_derivatives
#    - sec_document_info
#    - sec_footnotes
#    - sec_nonderivatives
#    ... (5 more tables)
#
# ✅ iri (15 datasets):
#    - db1983
#    - db1984
#    - db1985
#    - db1986
#    - db1987
#    - db1988
#    - db1989
#    - db1990
#    - db1991
#    - db1992
#    ... (5 more tables)
#
# ✅ iri_all (15 datasets):
#    - db1983
#    - db1984
#    - db1985
#    - db1986
#    - db1987
#    - db1988
#    - db1989
#    - db1990
#    - db1991
#    - db1992
#    ... (5 more tables)
#
# ✅ kpisamp (9 datasets):
#    - act_kpiint
#    - act_kpius
#    - chars
#    - companies
#    - det_kpiint
#    - det_kpius
#    - measures
#    - statsum_kpiint
#    - statsum_kpius
#
# ✅ macrofin (24 datasets):
#    - cay
#    - financial_uncertainty
#    - fxdata
#    - importportfolios
#    - macro_uncertainty
#    - port_eg_annual
#    - port_eg_daily
#    - port_eg_monthly
#    - port_eg_quarterly
#    - port_eg_weekly
#    ... (14 more tables)
#
# ✅ macrofin_comm_trade (24 datasets):
#    - cay
#    - financial_uncertainty
#    - fxdata
#    - importportfolios
#    - macro_uncertainty
#    - port_eg_annual
#    - port_eg_daily
#    - port_eg_monthly
#    - port_eg_quarterly
#    - port_eg_weekly
#    ... (14 more tables)
#
# ✅ midas (1 datasets):
#    - security
#
# ✅ morningstarsamp_cisdm (2 datasets):
#    - active_fund_info
#    - active_returns_assets
#
# ✅ mpsych_sample (1 datasets):
#    - sample
#
# ✅ mrktsamp (14 datasets):
#    - amereqty2011
#    - amereqtyi2011
#    - cds2011
#    - cdxcomps
#    - cdxconst
#    - chars
#    - corpbond2011
#    - corporatebonds2011
#    - g7bond2011
#    - govbonds2011
#    ... (4 more tables)
#
# ✅ mrktsamp_cds (2 datasets):
#    - cds2011
#    - chars
#
# ✅ mrktsamp_cdx (2 datasets):
#    - cdxcomps
#    - cdxconst
#
# ✅ mrktsamp_msf (11 datasets):
#    - amereqty2011
#    - amereqtyi2011
#    - chars
#    - corpbond2011
#    - corporatebonds2011
#    - g7bond2011
#    - govbonds2011
#    - govtbond2011
#    - msfa_chars
#    - msfachars
#    ... (1 more tables)
#
# ✅ msci_esg_samp (3 datasets):
#    - msci_esg_expanded
#    - msci_esg_ratings
#    - msci_esg_summary
#
# ✅ msciesmp (3 datasets):
#    - msci_esg_expanded
#    - msci_esg_ratings
#    - msci_esg_summary
#
# ✅ msrb (3 datasets):
#    - msrb
#    - msrb_lookup
#    - msrb_qvards
#
# ✅ msrb_all (3 datasets):
#    - msrb
#    - msrb_lookup
#    - msrb_qvards
#
# ✅ msrbsamp (1 datasets):
#    - msrb_trial
#
# ✅ msrbsamp_all (1 datasets):
#    - msrb_trial
#
# ✅ omtrial (24 datasets):
#    - distrd
#    - distribution
#    - exchgd
#    - historical_volatility
#    - hvold2014
#    - opinfd
#    - opprcd2014
#    - option_history
#    - option_price_2013
#    - optionmeurnames
#    ... (14 more tables)
#
# ✅ optionmsamp_europe (12 datasets):
#    - distribution
#    - historical_volatility
#    - option_history
#    - option_price_2013
#    - optionmeurnames
#    - security_name
#    - security_price
#    - std_option_price_2013
#    - tick_option_price_2013
#    - tick_std_option_price_2013
#    ... (2 more tables)
#
# ✅ optionmsamp_us (12 datasets):
#    - distrd
#    - exchgd
#    - hvold2014
#    - opinfd
#    - opprcd2014
#    - opvold
#    - secnmd
#    - secprd
#    - secprd2014
#    - securd1
#    ... (2 more tables)
#
# ✅ otc (1 datasets):
#    - endofday
#
# ✅ otc_endofday (1 datasets):
#    - endofday
#
# ✅ phlx (2 datasets):
#    - coph
#    - iv
#
# ✅ phlx_all (2 datasets):
#    - coph
#    - iv
#
# ✅ pitchsmp (19 datasets):
#    - pitchbk_qvards
#    - wrds_company
#    - wrds_companybuysiderelation
#    - wrds_companycompetitorrel
#    - wrds_companyemployeehistrel
#    - wrds_companyindustryrelation
#    - wrds_companyinvestorrelation
#    - wrds_companyverticalrelation
#    - wrds_deal
#    - wrds_dealdebtlenderrelation
#    ... (9 more tables)
#
# ✅ preqsamp (11 datasets):
#    - benchmarks
#    - buyoutdealsdetails
#    - cashflow
#    - funddetails
#    - fundhistoricperformance
#    - fundterms
#    - investordetails
#    - investorportfolio
#    - managerdetails
#    - managerinvestmenttypes
#    ... (1 more tables)
#
# ✅ preqsamp_all (11 datasets):
#    - benchmarks
#    - buyoutdealsdetails
#    - cashflow
#    - funddetails
#    - fundhistoricperformance
#    - fundterms
#    - investordetails
#    - investorportfolio
#    - managerdetails
#    - managerinvestmenttypes
#    ... (1 more tables)
#
# ✅ public (15 datasets):
#    - exp_per_event_table1
#    - exp_per_event_table2
#    - meps_exp_per_event_table1
#    - meps_exp_per_event_table2
#    - meps_top_prescribed
#    - meps_top_therapeutic_classes
#    - mepsins
#    - mepssumm
#    - mepssummexp_per_condition
#    - pg_buffercache
#    ... (5 more tables)
#
# ✅ public_all (11 datasets):
#    - exp_per_event_table1
#    - exp_per_event_table2
#    - meps_exp_per_event_table1
#    - meps_exp_per_event_table2
#    - meps_top_prescribed
#    - meps_top_therapeutic_classes
#    - mepsins
#    - mepssumm
#    - mepssummexp_per_condition
#    - top_prescribed
#    ... (1 more tables)
#
# ✅ pwt (7 datasets):
#    - na
#    - na70
#    - pwt61
#    - pwt62
#    - pwt63
#    - pwt70
#    - pwt71
#
# ✅ pwt_all (7 datasets):
#    - na
#    - na70
#    - pwt61
#    - pwt62
#    - pwt63
#    - pwt70
#    - pwt71
#
# ✅ ravenpack_trial (8 datasets):
#    - chars
#    - rpa_entity_mappings
#    - rpa_full_equities
#    - rpa_full_global_macro
#    - rpa_source_list
#    - rpa_taxonomy
#    - wrds_rpa_all_mappings
#    - wrds_rpa_company_names
#
# ✅ reprisk_sample (11 datasets):
#    - pm_company_identifiers
#    - pm_issue_data
#    - pm_location_data
#    - pm_news_data
#    - pm_rri_data
#    - pm_tag_data
#    - reprisk_company_lookup
#    - v2_company_identifiers
#    - v2_metrics
#    - v2_risk_incidents
#    ... (1 more tables)
#
# ✅ repsamp (11 datasets):
#    - pm_company_identifiers
#    - pm_issue_data
#    - pm_location_data
#    - pm_news_data
#    - pm_rri_data
#    - pm_tag_data
#    - reprisk_company_lookup
#    - v2_company_identifiers
#    - v2_metrics
#    - v2_risk_incidents
#    ... (1 more tables)
#
# ✅ revelio_samp (18 datasets):
#    - company_mapping
#    - individual_positions
#    - individual_positions_raw
#    - individual_role_lookup
#    - individual_user
#    - individual_user_education
#    - individual_user_education_raw
#    - individual_user_raw
#    - individual_user_skill_lookup
#    - individual_user_skills
#    ... (8 more tables)
#
# ✅ revsamp (18 datasets):
#    - company_mapping
#    - individual_positions
#    - individual_positions_raw
#    - individual_role_lookup
#    - individual_user
#    - individual_user_education
#    - individual_user_education_raw
#    - individual_user_raw
#    - individual_user_skill_lookup
#    - individual_user_skills
#    ... (8 more tables)
#
# ✅ risksamp (27 datasets):
#    - beneown
#    - bhown
#    - chars
#    - companyfy
#    - comppeer
#    - consultant
#    - dircomp
#    - exervest
#    - globalvoteresults
#    - gpbaabs
#    ... (17 more tables)
#
# ✅ risksamp_all (27 datasets):
#    - beneown
#    - bhown
#    - chars
#    - companyfy
#    - comppeer
#    - consultant
#    - dircomp
#    - exervest
#    - globalvoteresults
#    - gpbaabs
#    ... (17 more tables)
#
# ✅ rpnasamp (8 datasets):
#    - chars
#    - rpa_entity_mappings
#    - rpa_full_equities
#    - rpa_full_global_macro
#    - rpa_source_list
#    - rpa_taxonomy
#    - wrds_rpa_all_mappings
#    - wrds_rpa_company_names
#
# ✅ rq_all (1 datasets):
#    - rq_data
#
# ✅ rstat_samp (1 datasets):
#    - royalties
#
# ✅ rstatsmp (1 datasets):
#    - royalties
#
# ✅ sdcsamp (16 datasets):
#    - calldata
#    - deals_data
#    - ma_advisors
#    - ma_details
#    - ma_events
#    - maturity
#    - ni_details
#    - ratings
#    - sdc_joint_ventures
#    - wrds_bo_fund_firm
#    ... (6 more tables)
#
# ✅ secsamp (34 datasets):
#    - _forms_
#    - _names_
#    - _qvards_
#    - _regtypes_
#    - bow_2022
#    - bow_cossim
#    - bow_filingsummary
#    - bow_wordsummary
#    - chars
#    - derivatives
#    ... (24 more tables)
#
# ✅ secsamp_all (34 datasets):
#    - _forms_
#    - _names_
#    - _qvards_
#    - _regtypes_
#    - bow_2022
#    - bow_cossim
#    - bow_filingsummary
#    - bow_wordsummary
#    - chars
#    - derivatives
#    ... (24 more tables)
#
# ✅ snapsamp (10 datasets):
#    - chars
#    - wrds_cs_names
#    - wrds_csa_pit
#    - wrds_csa_pit_sorted
#    - wrds_csa_restated
#    - wrds_csa_unrestated
#    - wrds_csq_pit
#    - wrds_csq_pit_sorted
#    - wrds_csq_restated
#    - wrds_csq_unrestated
#
# ✅ snlsamp (4 datasets):
#    - chars
#    - wrds_fig_flowperiod_primary
#    - wrds_fig_stockperiod_primary
#    - wrds_institutions
#
# ✅ snlsamp_fig (4 datasets):
#    - chars
#    - wrds_fig_flowperiod_primary
#    - wrds_fig_stockperiod_primary
#    - wrds_institutions
#
# ✅ sustainalyticssamp_all (4 datasets):
#    - chars
#    - hist_raw_score
#    - hist_weighted_score
#    - hist_weights
#
# ✅ sustsamp (4 datasets):
#    - chars
#    - hist_raw_score
#    - hist_weighted_score
#    - hist_weights
#
# ✅ taqmsamp (58 datasets):
#    - arca_idf_x100_20211004
#    - arca_idf_x100_20211005
#    - arca_idf_x101_20211004
#    - arca_idf_x101_20211005
#    - arca_idf_x102_20211004
#    - arca_idf_x102_20211005
#    - arca_idf_x103_20211004
#    - arca_idf_x103_20211005
#    - arca_idf_x104_20211004
#    - arca_idf_x104_20211005
#    ... (48 more tables)
#
# ✅ taqmsamp_all (58 datasets):
#    - arca_idf_x100_20211004
#    - arca_idf_x100_20211005
#    - arca_idf_x101_20211004
#    - arca_idf_x101_20211005
#    - arca_idf_x102_20211004
#    - arca_idf_x102_20211005
#    - arca_idf_x103_20211004
#    - arca_idf_x103_20211005
#    - arca_idf_x104_20211004
#    - arca_idf_x104_20211005
#    ... (48 more tables)
#
# ✅ taqsamp (64 datasets):
#    - arca_idf_x101_20211004
#    - arca_idf_x101_20211005
#    - arca_idf_x102_20211004
#    - arca_idf_x102_20211005
#    - arca_idf_x103_20211004
#    - arca_idf_x103_20211005
#    - arca_idf_x104_20211004
#    - arca_idf_x104_20211005
#    - arca_idf_x105_20211004
#    - arca_idf_x105_20211005
#    ... (54 more tables)
#
# ✅ taqsamp_all (14 datasets):
#    - cq0002
#    - cq_20080107
#    - cq_20080108
#    - cq_20080109
#    - cq_20080110
#    - cq_20080111
#    - ct0002
#    - ct_20080107
#    - ct_20080108
#    - ct_20080109
#    ... (4 more tables)
#
# ✅ totalq (1 datasets):
#    - total_q
#
# ✅ totalq_all (1 datasets):
#    - total_q
#
# ✅ tr_sdc_samples (12 datasets):
#    - calldata
#    - deals_data
#    - maturity
#    - ratings
#    - sdc_joint_ventures
#    - wrds_bo_fund_firm
#    - wrds_bo_fundra_fund
#    - wrds_bo_invdtl_compn_fund
#    - wrds_managers
#    - wrds_vc_fund_firm
#    ... (2 more tables)
#
# ✅ trace (34 datasets):
#    - absmasterfile
#    - camasterfile
#    - cmomasterfile
#    - masterfile
#    - mbsmasterfile
#    - tbamasterfile
#    - trace
#    - trace_agency
#    - trace_agency_names
#    - trace_btds144a
#    ... (24 more tables)
#
# ✅ trace_enhanced (2 datasets):
#    - camasterfile
#    - trace_enhanced
#
# ✅ trace_standard (32 datasets):
#    - absmasterfile
#    - camasterfile
#    - cmomasterfile
#    - mbsmasterfile
#    - tbamasterfile
#    - trace
#    - trace_agency
#    - trace_agency_names
#    - trace_btds144a
#    - trace_btds144a_names
#    ... (22 more tables)
#
# ✅ trcstsmp (15 datasets):
#    - _chars_
#    - wrds_carbon_data
#    - wrds_carbon_forecast
#    - wrds_companies
#    - wrds_data_items
#    - wrds_environment
#    - wrds_esg
#    - wrds_esg_facts
#    - wrds_ff_data
#    - wrds_ff_sector
#    ... (5 more tables)
#
# ✅ trdbdmismp (1 datasets):
#    - dandb_dmi_us_2023
#
# ✅ trdbwbsmp (8 datasets):
#    - dandb_wb_ap_business_2023
#    - dandb_wb_ap_delete_2023
#    - dandb_wb_ap_link_2023
#    - dandb_wb_ap_unlnk_2023
#    - dandb_wb_eu_business_2023
#    - dandb_wb_eu_delete_2023
#    - dandb_wb_eu_link_2023
#    - dandb_wb_eu_unlnk_2023
#
# ✅ trdssamp (19 datasets):
#    - ds2mktval
#    - ds2primqtprc
#    - ds2primqtri
#    - dscminfo
#    - dsfutcontrinfo
#    - ecodata
#    - ecoinfo
#    - wrds_cmdy_data
#    - wrds_cmdy_info
#    - wrds_contract_info
#    ... (9 more tables)
#
# ✅ tresgsmp (1 datasets):
#    - wrds_ref_esg
#
# ✅ trsamp (21 datasets):
#    - det_guidance
#    - productperformance
#    - wrds_company_cg
#    - wrds_company_ec
#    - wrds_company_en
#    - wrds_company_info
#    - wrds_company_smry
#    - wrds_company_so
#    - wrds_esg_boardmem
#    - wrds_esg_drivers
#    ... (11 more tables)
#
# ✅ trsamp_all (13 datasets):
#    - det_guidance
#    - productperformance
#    - wrds_company_cg
#    - wrds_company_ec
#    - wrds_company_en
#    - wrds_company_info
#    - wrds_company_smry
#    - wrds_company_so
#    - wrds_esg_boardmem
#    - wrds_esg_drivers
#    ... (3 more tables)
#
# ✅ trsamp_db_dmi (1 datasets):
#    - dandb_dmi_us_2023
#
# ✅ trsamp_db_wb (8 datasets):
#    - dandb_wb_ap_business_2023
#    - dandb_wb_ap_delete_2023
#    - dandb_wb_ap_link_2023
#    - dandb_wb_ap_unlnk_2023
#    - dandb_wb_eu_business_2023
#    - dandb_wb_eu_delete_2023
#    - dandb_wb_eu_link_2023
#    - dandb_wb_eu_unlnk_2023
#
# ✅ trsamp_ds_eq (8 datasets):
#    - ds2mktval
#    - ds2primqtprc
#    - ds2primqtri
#    - wrds_ds2dsf
#    - wrds_ds_indexconstmerged_dly
#    - wrds_ds_indexconstmerged_mth
#    - wrds_ds_indexmerged
#    - wrds_ds_names
#
# ✅ trsamp_dscom (3 datasets):
#    - dscminfo
#    - wrds_cmdy_data
#    - wrds_cmdy_info
#
# ✅ trsamp_dsecon (3 datasets):
#    - ecodata
#    - ecoinfo
#    - wrds_ecoinfo
#
# ✅ trsamp_dsfut (5 datasets):
#    - dsfutcontrinfo
#    - wrds_contract_info
#    - wrds_cseries_info
#    - wrds_fut_contract
#    - wrds_fut_series
#
# ✅ trsamp_esg (1 datasets):
#    - wrds_ref_esg
#
# ✅ trsamp_sdc_ma (3 datasets):
#    - ma_advisors
#    - ma_details
#    - ma_events
#
# ✅ trsamp_sdc_ni (1 datasets):
#    - ni_details
#
# ✅ trsamp_worldscope (8 datasets):
#    - wrds_ws_company
#    - wrds_ws_funda
#    - wrds_ws_fundq
#    - wrds_ws_ids
#    - wrds_ws_pension
#    - wrds_ws_segments
#    - wrds_ws_stock
#    - wrds_ws_stock_header
#
# ✅ trucost_samp (15 datasets):
#    - _chars_
#    - wrds_carbon_data
#    - wrds_carbon_forecast
#    - wrds_companies
#    - wrds_data_items
#    - wrds_environment
#    - wrds_esg
#    - wrds_esg_facts
#    - wrds_ff_data
#    - wrds_ff_sector
#    ... (5 more tables)
#
# ✅ twoiq_samp (3 datasets):
#    - chars
#    - insiderfeedglobal
#    - insiderfeedglobalaggregated
#
# ✅ twoiqsmp (3 datasets):
#    - chars
#    - insiderfeedglobal
#    - insiderfeedglobalaggregated
#
# ✅ wappsamp (12 datasets):
#    - ccmxpf_lnkhist
#    - ciqkeydev
#    - ciqkeydevint
#    - country
#    - dsedelist
#    - dsf
#    - dsi
#    - g_secd
#    - g_security
#    - series_data
#    ... (2 more tables)
#
# ✅ wenvsmp (4 datasets):
#    - wrds_air
#    - wrds_facilities
#    - wrds_geography
#    - wrds_water
#
# ✅ wmfsmp (21 datasets):
#    - fund_12b1_payments
#    - fund_administrator
#    - fund_adviser
#    - fund_advisory_contract
#    - fund_alt_investment
#    - fund_balance_sheet
#    - fund_broker_dealer
#    - fund_broker_relations
#    - fund_custodian
#    - fund_debt_invest
#    ... (11 more tables)
#
# ✅ wrds_environmental_samp (4 datasets):
#    - wrds_air
#    - wrds_facilities
#    - wrds_geography
#    - wrds_water
#
# ✅ wrds_insiders_samp (15 datasets):
#    - fdic_derivatives
#    - fdic_document_info
#    - fdic_footnotes
#    - fdic_nonderivatives
#    - fdic_reporting_owners
#    - fdic_signatures
#    - sec_derivatives
#    - sec_document_info
#    - sec_footnotes
#    - sec_nonderivatives
#    ... (5 more tables)
#
# ✅ wrds_lib_internal (1 datasets):
#    - friendly_schema_mapping
#
# ✅ wrds_mutualfund_samp (21 datasets):
#    - fund_12b1_payments
#    - fund_administrator
#    - fund_adviser
#    - fund_advisory_contract
#    - fund_alt_investment
#    - fund_balance_sheet
#    - fund_broker_dealer
#    - fund_broker_relations
#    - fund_custodian
#    - fund_debt_invest
#    ... (11 more tables)
#
# ✅ wrdsapps (71 datasets):
#    - _eq_2_bm_
#    - bdxcrspcomplink
#    - bdxinslink
#    - boardex_ciq
#    - boardex_ciq_link
#    - boardex_trinsider
#    - boardex_trinsider_link
#    - boardex_twoiq
#    - boardex_twoiq_link
#    - bondcrsp_link
#    ... (61 more tables)
#
# ✅ wrdsapps_eushort (1 datasets):
#    - eushort
#
# ✅ wrdsapps_evtstudy_int (2 datasets):
#    - intl_market_values
#    - intl_security_returns
#
# ✅ wrdsapps_evtstudy_us (2 datasets):
#    - usa_market_values
#    - usa_security_returns
#
# ✅ wrdsapps_finratio (2 datasets):
#    - firm_ratio
#    - id
#
# ✅ wrdsapps_link_comp_eushort (1 datasets):
#    - compeushortlink
#
# ✅ wrdsapps_link_crsp_bond (1 datasets):
#    - bondcrsp_link
#
# ✅ wrdsapps_link_crsp_factset (1 datasets):
#    - fscrsplink
#
# ✅ wrdsapps_link_crsp_taq (1 datasets):
#    - tclink
#
# ✅ wrdsapps_patents (3 datasets):
#    - uspatents_citations
#    - uspatents_gvkey_linking
#    - uspatents_meta
#
# ✅ wrdsapps_subsidiary (2 datasets):
#    - chars
#    - wrds_relationships
#
# ✅ wrdsapps_windices (3 datasets):
#    - dwcountryreturns
#    - mwcountryreturns
#    - wcountryconstituents
#
# ✅ wrdsappssamp_all (12 datasets):
#    - ccmxpf_lnkhist
#    - ciqkeydev
#    - ciqkeydevint
#    - country
#    - dsedelist
#    - dsf
#    - dsi
#    - g_secd
#    - g_security
#    - series_data
#    ... (2 more tables)
#
# ✅ wrdssec_midas (1 datasets):
#    - security
#
# ✅ zacksamp (17 datasets):
#    - company_info
#    - eps_actuals
#    - eps_cons_daily
#    - eps_cons_weekly
#    - eps_detail
#    - eps_ltg_cons_daily
#    - eps_ltg_cons_weekly
#    - eps_surp
#    - preann
#    - ratings_cons_daily
#    ... (7 more tables)
#
# ✅ zacksamp_all (17 datasets):
#    - company_info
#    - eps_actuals
#    - eps_cons_daily
#    - eps_cons_weekly
#    - eps_detail
#    - eps_ltg_cons_daily
#    - eps_ltg_cons_weekly
#    - eps_surp
#    - preann
#    - ratings_cons_daily
#    ... (7 more tables)

# %%
full_table = [i for i in libraries if ('samp' not in i) and ('trial' not in i)]
full_table
# Out:
# ['auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'block',
#  'block_all',
#  'boardsmp',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'cisdmsmp',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_monthly_all',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'compa',
#  'compb',
#  'compg',
#  'compm',
#  'compseg',
#  'contrib',
#  'contrib_as_filed_financials',
#  'contrib_char_returns',
#  'contrib_corporate_culture',
#  'contrib_general',
#  'contrib_global_factor',
#  'contrib_intangible_value',
#  'contrib_kpss',
#  'contrib_liva',
#  'crsp',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_a_treasuries',
#  'csmar',
#  'csmar_af',
#  'csmar_cd',
#  'csmar_cg',
#  'csmar_colc',
#  'csmar_financial',
#  'csmar_funds',
#  'csmar_hld',
#  'csmar_ini',
#  'csmar_ipo_a',
#  'csmar_ma',
#  'csmar_rs',
#  'csmar_trade',
#  'djones',
#  'djones_all',
#  'dmef',
#  'dmef_all',
#  'doe',
#  'doe_all',
#  'ff',
#  'ff_all',
#  'fjc',
#  'fjc_linking',
#  'fjc_litigation',
#  'frb',
#  'frb_all',
#  'gutenberg',
#  'iri',
#  'iri_all',
#  'macrofin',
#  'macrofin_comm_trade',
#  'midas',
#  'msciesmp',
#  'msrb',
#  'msrb_all',
#  'otc',
#  'otc_endofday',
#  'phlx',
#  'phlx_all',
#  'pitchsmp',
#  'public',
#  'public_all',
#  'pwt',
#  'pwt_all',
#  'rq_all',
#  'rstatsmp',
#  'totalq',
#  'totalq_all',
#  'trace',
#  'trace_enhanced',
#  'trace_standard',
#  'trcstsmp',
#  'trdbdmismp',
#  'trdbwbsmp',
#  'tresgsmp',
#  'twoiqsmp',
#  'wenvsmp',
#  'wmfsmp',
#  'wrds_lib_internal',
#  'wrdsapps',
#  'wrdsapps_eushort',
#  'wrdsapps_evtstudy_int',
#  'wrdsapps_evtstudy_us',
#  'wrdsapps_finratio',
#  'wrdsapps_link_comp_eushort',
#  'wrdsapps_link_crsp_bond',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_patents',
#  'wrdsapps_subsidiary',
#  'wrdsapps_windices',
#  'wrdssec_midas']

# %%
dir(db)
# Out:
# ['_Connection__check_schema_perms',
#  '_Connection__create_pgpass_file_unix',
#  '_Connection__create_pgpass_file_win32',
#  '_Connection__get_schema_for_view',
#  '_Connection__get_user_credentials',
#  '_Connection__make_sa_engine_conn',
#  '_Connection__write_pgpass_file',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_connect_args',
#  '_dbname',
#  '_hostname',
#  '_password',
#  '_port',
#  '_username',
#  '_verbose',
#  'close',
#  'connect',
#  'connection',
#  'create_pgpass_file',
#  'describe_table',
#  'engine',
#  'get_row_count',
#  'get_table',
#  'insp',
#  'list_libraries',
#  'list_tables',
#  'load_library_list',
#  'raw_sql',
#  'schema_perm']

# %%
db.list_tables('block')
# Out:
# ['block', 'block2', 'blockw']

# %%
help(db.raw_sql)
# Out:
# Help on method raw_sql in module wrds.sql:
#
# raw_sql(sql, coerce_float=True, date_cols=None, index_col=None, params=None, chunksize=500000, return_iter=False, dtype=None, dtype_backend='numpy_nullable') method of wrds.sql.Connection instance
#     Queries the database using a raw SQL string.
#
#     :param sql: SQL code in string object.
#     :param coerce_float: (optional) boolean, default: True
#         Attempts to convert values of non-string, non-numeric objects
#         to floating point. Can result in loss of precision.
#     :param date_cols: (optional) list or dict, default: None
#         - List of column names to parse as date
#         - Dict of ``{column_name: format string}`` where
#             format string is:
#               strftime compatible in case of parsing string times or
#               is one of (D, s, ns, ms, us) in case of parsing
#                 integer timestamps
#         - Dict of ``{column_name: arg dict}``,
#             where the arg dict corresponds to the keyword arguments of
#               :func:`pandas.to_datetime`
#     :param index_col: (optional) string or list of strings,
#       default: None
#         Column(s) to set as index(MultiIndex)
#     :param params: parameters to SQL query, if parameterized.
#     :param chunksize: (optional) integer or None default: 500000
#         Process query in chunks of this size. Smaller chunksizes can save
#         a considerable amount of memory while query is being processed.
#         Set to None run query w/o chunking.
#     :param return_iter: (optional) boolean, default:False
#         When chunksize is not None, return an iterator where chunksize
#         number of rows is included in each chunk.
#     :param dtype: (optional) Type name or dict of columns
#       default: None
#         Data type for data or columns. E.g. np.float64 or
#         {'a': np.float64, 'b': np.int32, 'c': 'Int64'}.
#     :param dtype_backend: (optional) string
#       default: "numpy_nullable"
#         Allow backend storage type to be changed. e.g. "pyarrow"
#
#     :rtype: pandas.DataFrame or or Iterator[pandas.DataFrame]
#
#
#     Usage ::
#     # Basic Usage
#     >>> data = db.raw_sql('select cik, fdate, coname from wrdssec_all.dforms;', date_cols=['fdate'], index_col='cik')
#     >>> data.head()
#         cik        fdate       coname
#         0000000003 1995-02-15  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1996-02-14  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1997-02-19  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1998-03-02  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1998-03-10  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y..
#         ...
#
#     # Parameterized SQL query
#     >>> parm = {'syms': ('A', 'AA', 'AAPL'), 'num_shares': 50000}
#     >>> data = db.raw_sql('select * from taqmsec.ctm_20030910 where sym_root in %(syms)s and size > %(num_shares)s', params=parm)
#     >>> data.head()
#               date           time_m ex sym_root sym_suffix tr_scond      size   price tr_stopind tr_corr     tr_seqnum tr_source tr_rf
#         2003-09-10  11:02:09.485000  T        A       None     None  211400.0  25.350          N      00  1.929952e+15         C  None
#         2003-09-10  11:04:29.508000  N        A       None     None   55500.0  25.180          N      00  1.929952e+15         C  None
#         2003-09-10  15:08:21.155000  N        A       None     None   50500.0  24.470          N      00  1.929967e+15         C  None
#         2003-09-10  16:10:35.522000  T        A       None        B   71900.0  24.918          N      00  1.929970e+15         C  None
#         2003-09-10  09:35:20.709000  N       AA       None     None  108100.0  28.200          N      00  1.929947e+15         C  None

# %%
db.raw_sql(f"SELECT COUNT(*) FROM block.block")
# Out:
#    count
# 0  20975

# %%
# Step 1: Get all libraries
libraries = db.list_libraries()

# Step 2: Initialize list to hold accessible tables
accessible_tables = []

# Step 3: Loop through libraries and tables
for lib in libraries:
    try:
        tables = db.list_tables(library=lib)
    except:
        continue  # Skip libraries that can't even be listed

    for table in tables:
        qualified_name = f"{lib}.{table}"
        try:
            # Try a minimal query — only 1 row
            db.raw_sql(f"SELECT * FROM {qualified_name} LIMIT 1;")
            accessible_tables.append(qualified_name)
        except Exception as e:
            continue  # Permission denied or other query failure

# Step 4: Output results
print("✅ Fully accessible WRDS datasets:")
print(accessible_tables)
# Out:
# ✅ Fully accessible WRDS datasets:
# ['aha_sample.annual_survey', 'ahasamp.annual_survey', 'auditsmp.accfiler', 'auditsmp.auditcblock', 'auditsmp.auditchange', 'auditsmp.auditfees', 'auditsmp.auditfeesr', 'auditsmp.auditnonreli', 'auditsmp.auditopin', 'auditsmp.auditors', 'auditsmp.auditorsinfo', 'auditsmp.auditsox302', 'auditsmp.auditsox404', 'auditsmp.benefit', 'auditsmp.diroffichange', 'auditsmp.nt', 'auditsmp.revauditopin', 'auditsmp_all.accfiler', 'auditsmp_all.auditcblock', 'auditsmp_all.auditchange', 'auditsmp_all.auditfees', 'auditsmp_all.auditfeesr', 'auditsmp_all.auditnonreli', 'auditsmp_all.auditopin', 'auditsmp_all.auditors', 'auditsmp_all.auditorsinfo', 'auditsmp_all.auditsox302', 'auditsmp_all.auditsox404', 'auditsmp_all.benefit', 'auditsmp_all.diroffichange', 'auditsmp_all.nt', 'auditsmp_all.revauditopin', 'bank.wrds_bank_crsp_link', 'bank.wrds_bank_reg_vars', 'bank.wrds_call_rcfa_1', 'bank.wrds_call_rcfd_1', 'bank.wrds_call_rcfd_2', 'bank.wrds_call_rcfn_1', 'bank.wrds_call_rcfw_1', 'bank.wrds_call_rcoa_1', 'bank.wrds_call_rcon_1', 'bank.wrds_call_rcon_2', 'bank.wrds_call_rcow_1', 'bank.wrds_call_riad_1', 'bank.wrds_call_te_1', 'bank.wrds_holding_bhck_1', 'bank.wrds_holding_bhck_2', 'bank.wrds_holding_other_1', 'bank.wrds_struct_attributes_active', 'bank.wrds_struct_attributes_branches', 'bank.wrds_struct_attributes_closed', 'bank.wrds_struct_relationships', 'bank.wrds_struct_transformations', 'bank_all.wrds_bank_crsp_link', 'bank_all.wrds_bank_reg_vars', 'bank_all.wrds_call_rcfa_1', 'bank_all.wrds_call_rcfd_1', 'bank_all.wrds_call_rcfd_2', 'bank_all.wrds_call_rcfn_1', 'bank_all.wrds_call_rcfw_1', 'bank_all.wrds_call_rcoa_1', 'bank_all.wrds_call_rcon_1', 'bank_all.wrds_call_rcon_2', 'bank_all.wrds_call_rcow_1', 'bank_all.wrds_call_riad_1', 'bank_all.wrds_call_te_1', 'bank_all.wrds_holding_bhck_1', 'bank_all.wrds_holding_bhck_2', 'bank_all.wrds_holding_other_1', 'bank_all.wrds_struct_attributes_active', 'bank_all.wrds_struct_attributes_branches', 'bank_all.wrds_struct_attributes_closed', 'bank_all.wrds_struct_relationships', 'bank_all.wrds_struct_transformations', 'bank_premium_samp.bic_to_lei', 'bank_premium_samp.idrssd_to_lei', 'bank_premium_samp.isin_to_lei', 'bank_premium_samp.lei_main', 'bank_premium_samp.rel_main', 'bank_premium_samp.wrds_call_derived', 'bank_premium_samp.wrds_call_frgn_rcfd', 'bank_premium_samp.wrds_call_research', 'bank_premium_samp.wrds_struct_rel_ultimate', 'banksamp.bic_to_lei', 'banksamp.idrssd_to_lei', 'banksamp.isin_to_lei', 'banksamp.lei_main', 'banksamp.rel_main', 'banksamp.wrds_call_derived', 'banksamp.wrds_call_frgn_rcfd', 'banksamp.wrds_call_research', 'banksamp.wrds_struct_rel_ultimate', 'block.block', 'block.block2', 'block.blockw', 'block_all.block', 'block_all.block2', 'block_all.blockw', 'boardex_trial.jr_board_characteristics', 'boardex_trial.jr_board_dir_announcements', 'boardex_trial.jr_board_dir_committees', 'boardex_trial.jr_board_education_assoc', 'boardex_trial.jr_board_listed_assoc', 'boardex_trial.jr_board_nfp_assoc', 'boardex_trial.jr_board_other_assoc', 'boardex_trial.jr_board_unlisted_assoc', 'boardex_trial.jr_company_profile_advisors', 'boardex_trial.jr_company_profile_details', 'boardex_trial.jr_company_profile_market_cap', 'boardex_trial.jr_company_profile_sr_mgrs', 'boardex_trial.jr_company_profile_stocks', 'boardex_trial.jr_dir_characteristics', 'boardex_trial.jr_dir_education_assoc', 'boardex_trial.jr_dir_listed_assoc', 'boardex_trial.jr_dir_nfp_assoc', 'boardex_trial.jr_dir_other_assoc', 'boardex_trial.jr_dir_profile_achievements', 'boardex_trial.jr_dir_profile_details', 'boardex_trial.jr_dir_profile_education', 'boardex_trial.jr_dir_profile_emp', 'boardex_trial.jr_dir_profile_other_activ', 'boardex_trial.jr_dir_standard_remun', 'boardex_trial.jr_dir_unlisted_assoc', 'boardex_trial.jr_ltip_compensation', 'boardex_trial.jr_ltip_wealth', 'boardex_trial.jr_options_compensation', 'boardex_trial.jr_options_wealth', 'boardex_trial.jr_wrds_company_dir_names', 'boardex_trial.jr_wrds_company_names', ...

# %%
available_tables = [i for i in accessible_tables if ('samp' not in i) and ('trial' not in i) and ('smp' not in i)]
print(available_tables)
# Out:
# ['bank.wrds_bank_crsp_link', 'bank.wrds_bank_reg_vars', 'bank.wrds_call_rcfa_1', 'bank.wrds_call_rcfd_1', 'bank.wrds_call_rcfd_2', 'bank.wrds_call_rcfn_1', 'bank.wrds_call_rcfw_1', 'bank.wrds_call_rcoa_1', 'bank.wrds_call_rcon_1', 'bank.wrds_call_rcon_2', 'bank.wrds_call_rcow_1', 'bank.wrds_call_riad_1', 'bank.wrds_call_te_1', 'bank.wrds_holding_bhck_1', 'bank.wrds_holding_bhck_2', 'bank.wrds_holding_other_1', 'bank.wrds_struct_attributes_active', 'bank.wrds_struct_attributes_branches', 'bank.wrds_struct_attributes_closed', 'bank.wrds_struct_relationships', 'bank.wrds_struct_transformations', 'bank_all.wrds_bank_crsp_link', 'bank_all.wrds_bank_reg_vars', 'bank_all.wrds_call_rcfa_1', 'bank_all.wrds_call_rcfd_1', 'bank_all.wrds_call_rcfd_2', 'bank_all.wrds_call_rcfn_1', 'bank_all.wrds_call_rcfw_1', 'bank_all.wrds_call_rcoa_1', 'bank_all.wrds_call_rcon_1', 'bank_all.wrds_call_rcon_2', 'bank_all.wrds_call_rcow_1', 'bank_all.wrds_call_riad_1', 'bank_all.wrds_call_te_1', 'bank_all.wrds_holding_bhck_1', 'bank_all.wrds_holding_bhck_2', 'bank_all.wrds_holding_other_1', 'bank_all.wrds_struct_attributes_active', 'bank_all.wrds_struct_attributes_branches', 'bank_all.wrds_struct_attributes_closed', 'bank_all.wrds_struct_relationships', 'bank_all.wrds_struct_transformations', 'block.block', 'block.block2', 'block.blockw', 'block_all.block', 'block_all.block2', 'block_all.blockw', 'calcbnch.breakout', 'calcbnch.entity_names', 'calcbnch.normalized_fn', 'cboe.cboe', 'cboe_all.cboe', 'columnar.chunk', 'columnar.chunk_group', 'columnar.options', 'columnar.storage', 'columnar.stripe', 'comp.aco_amda', 'comp.aco_imda', 'comp.aco_indfnta', 'comp.aco_indfntq', 'comp.aco_indfntytd', 'comp.aco_indsta', 'comp.aco_indstq', 'comp.aco_indstytd', 'comp.aco_notesa', 'comp.aco_notesq', 'comp.aco_notessa', 'comp.aco_notesytd', 'comp.aco_pnfnda', 'comp.aco_pnfndq', 'comp.aco_pnfndytd', 'comp.aco_pnfnta', 'comp.aco_pnfntq', 'comp.aco_pnfntytd', 'comp.aco_transa', 'comp.aco_transq', 'comp.aco_transsa', 'comp.aco_transytd', 'comp.adsprate', 'comp.asec_amda', 'comp.asec_imda', 'comp.asec_notesa', 'comp.asec_notesq', 'comp.asec_transa', 'comp.asec_transq', 'comp.bank_aacctchg', 'comp.bank_adesind', 'comp.bank_afnd1', 'comp.bank_afnd2', 'comp.bank_afnddc1', 'comp.bank_afnddc2', 'comp.bank_afntind', 'comp.bank_funda', 'comp.bank_funda_fncd', 'comp.bank_fundq', 'comp.bank_fundq_fncd', 'comp.bank_iacctchg', 'comp.bank_idesind', 'comp.bank_ifndq', 'comp.bank_ifndytd', 'comp.bank_ifntq', 'comp.bank_ifntytd', 'comp.bank_names', 'comp.bank_namesq', 'comp.chars', 'comp.co_aacctchg', 'comp.co_aaudit', 'comp.co_acthist', 'comp.co_adesind', 'comp.co_adjfact', 'comp.co_afnd1', 'comp.co_afnd2', 'comp.co_afnddc1', 'comp.co_afnddc2', 'comp.co_afntind1', 'comp.co_afntind2', 'comp.co_ainvval', 'comp.co_amkt', 'comp.co_busdescl', 'comp.co_cotype', 'comp.co_filedate', 'comp.co_fortune', 'comp.co_hgic', 'comp.co_iacctchg', 'comp.co_iaudit', 'comp.co_idesind', 'comp.co_ifndq', 'comp.co_ifndsa', 'comp.co_ifndytd', 'comp.co_ifntq', 'comp.co_ifntsa', 'comp.co_ifntytd', 'comp.co_imkt', 'comp.co_industry', 'comp.co_ipcd', 'comp.co_mthly', 'comp.co_offtitl', 'comp.company', 'comp.currency', 'comp.dd_group', 'comp.dd_group_xref', 'comp.dd_item', 'comp.dd_package', 'comp.ecind_desc', 'comp.ecind_mth', 'comp.exrt_dly', 'comp.exrt_mth', 'comp.funda', 'comp.funda_fncd', 'comp.fundq', 'comp.fundq_fncd', 'comp.g_bmiindex', 'comp.g_bmiindexdlynumvalue', 'comp.g_bmiindexidentifier', 'comp.g_bmiindexrel', 'comp.g_bmiindextradingitem', 'comp.g_chars', 'comp.g_co_aaudit', 'comp.g_co_adesind', 'comp.g_co_afnd1', 'comp.g_co_afnd2', 'comp.g_co_afnddc1', 'comp.g_co_afnddc2', 'comp.g_co_afntind1', 'comp.g_co_afntind2', 'comp.g_co_ainvval', 'comp.g_co_gsuppl', 'comp.g_co_hgic', 'comp.g_co_iaudit', 'comp.g_co_idesind', 'comp.g_co_ifndq', 'comp.g_co_ifndsa', 'comp.g_co_ifndytd', 'comp.g_co_ifntq', 'comp.g_co_ifntsa', 'comp.g_co_ifntytd', 'comp.g_co_industry', 'comp.g_co_ipcd', 'comp.g_co_offtitl', 'comp.g_compan ...

# %%
db.close()
